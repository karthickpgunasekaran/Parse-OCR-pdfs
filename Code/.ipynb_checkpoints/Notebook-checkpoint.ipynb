# %%
from tabula import read_pdf
from tabula import convert_into

# %%
df = read_pdf("../Sample_input_table_data/Roll_Call_5.pdf", pages="1-5")

#convert_into("../Sample_input_table_data/Roll_Call_1.pdf", "../Sample_output_table_data/Roll_Call_1.csv", output_format="csv", pages='2,3')
#print("hi")
# Out:
# Got stderr: Feb 11, 2020 2:58:21 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+57 (57) in font BXCJIM+LuxiSansRegularRegular
# Feb 11, 2020 2:58:21 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+72 (72) in font BXCJIM+LuxiSansRegularRegular
# Feb 11, 2020 2:58:21 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+85 (85) in font BXCJIM+LuxiSansRegularRegular
# Feb 11, 2020 2:58:21 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+75 (75) in font BXCJIM+LuxiSansRegularRegular
# Feb 11, 2020 2:58:21 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+68 (68) in font BXCJIM+LuxiSansRegularRegular
# Feb 11, 2020 2:58:21 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+81 (81) in font BXCJIM+LuxiSansRegularRegular
# Feb 11, 2020 2:58:21 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+71 (71) in font BXCJIM+LuxiSansRegularRegular
# Feb 11, 2020 2:58:21 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+79 (79) in font BXCJIM+LuxiSansRegularRegular
# Feb 11, 2020 2:58:21 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+88 (88) in font BXCJIM+LuxiSansRegularRegular
# Feb 11, 2020 2:58:21 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+74 (74) in font BXCJIM+LuxiSansRegularRegular
# Feb 11, 2020 2:58:21 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+3 (3) in font BXCJIM+LuxiSansRegularRegular
# Feb 11, 2020 2:58:21 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+86 (86) in font BXCJIM+LuxiSansRegularRegular
# Feb 11, 2020 2:58:21 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+53 (53) in font BXCJIM+LuxiSansRegularRegular
# Feb 11, 2020 2:58:21 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+76 (76) in font BXCJIM+LuxiSansRegularRegular
# Feb 11, 2020 2:58:21 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+70 (70) in font BXCJIM+LuxiSansRegularRegular
# Feb 11, 2020 2:58:21 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+87 (87) in font BXCJIM+LuxiSansRegularRegular
# Feb 11, 2020 2:58:21 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+37 (37) in font BXCJIM+LuxiSansRegularRegular
# Feb 11, 2020 2:58:21 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+17 (17) in font BXCJIM+LuxiSansRegularRegular
# Feb 11, 2020 2:58:21 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+29 (29) in font BXCJIM+LuxiSansRegularRegular
# Feb 11, 2020 2:58:21 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+22 (22) in font BXCJIM+LuxiSansRegularRegular
# Feb 11, 2020 2:58:21 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+27 (27) in font BXCJIM+LuxiSansRegularRegular
# Feb 11, 2020 2:58:21 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+25 (25) in font BXCJIM+LuxiSansRegularRegular
# Feb 11, 2020 2:58:21 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+20 (20) in font BXCJIM+LuxiSansRegularRegular
# Feb 11, 2020 2:58:21 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+28 (28) in font BXCJIM+LuxiSansRegularRegular
# Feb 11, 2020 2:58:21 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+21 (21) in font BXCJIM+LuxiSansRegularRegular
# Feb 11, 2020 2:58:21 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+23 (23) in font BXCJIM+LuxiSansRegularRegular
# Feb 11, 2020 2:58:21 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+24 (24) in font BXCJIM+LuxiSansRegularRegular
# Feb 11, 2020 2:58:21 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+45 (45) in font BXCJIM+LuxiSansRegularRegular
# Feb 11, 2020 2:58:21 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+83 (83) in font BXCJIM+LuxiSansRegularRegular
# Feb 11, 2020 2:58:21 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+69 (69) in font BXCJIM+LuxiSansRegularRegular
# Feb 11, 2020 2:58:21 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+92 (92) in font BXCJIM+LuxiSansRegularRegular
# Feb 11, 2020 2:58:21 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+15 (15) in font BXCJIM+LuxiSansRegularRegular
# Feb 11, 2020 2:58:21 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+36 (36) in font BXCJIM+LuxiSansRegularRegular
# Feb 11, 2020 2:58:21 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+16 (16) in font BXCJIM+LuxiSansRegularRegular
# Feb 11, 2020 2:58:21 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+89 (89) in font BXCJIM+LuxiSansRegularRegular
# Feb 11, 2020 2:58:21 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+19 (19) in font BXCJIM+LuxiSansRegularRegular
# Feb 11, 2020 2:58:21 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+26 (26) in font BXCJIM+LuxiSansRegularRegular
# Feb 11, 2020 2:58:21 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+39 (39) in font BXCJIM+LuxiSansRegularRegular
# Feb 11, 2020 2:58:21 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+51 (51) in font BXCJIM+LuxiSansRegularRegular
# Feb 11, 2020 2:58:21 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+41 (41) in font BXCJIM+LuxiSansRegularRegular
# Feb 11, 2020 2:58:21 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+78 (78) in font BXCJIM+LuxiSansRegularRegular
# Feb 11, 2020 2:58:21 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+82 (82) in font BXCJIM+LuxiSansRegularRegular
# Feb 11, 2020 2:58:21 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+90 (90) in font BXCJIM+LuxiSansRegularRegular
# Feb 11, 2020 2:58:21 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+57 (57) in font BXCJIM+LuxiSansRegularRegular
# Feb 11, 2020 2:58:21 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+72 (72) in font BXCJIM+LuxiSansRegularRegular
# Feb 11, 2020 2:58:21 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+85 (85) in font BXCJIM+LuxiSansRegularRegular
# Feb 11, 2020 2:58:21 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+75 (75) in font BXCJIM+LuxiSansRegularRegular
# Feb 11, 2020 2:58:21 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+68 (68) in font BXCJIM+LuxiSansRegularRegular
# Feb 11, 2020 2:58:21 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+81 (81) in font BXCJIM+LuxiSansRegularRegular
# Feb 11, 2020 2:58:21 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+71 (71) in font BXCJIM+LuxiSansRegularRegular
# Feb 11, 2020 2:58:21 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+79 (79) in font BXCJIM+LuxiSansRegularRegular
# Feb 11, 2020 2:58:21 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+88 (88) in font BXCJIM+LuxiSansRegularRegular
# Feb 11, 2020 2:58:21 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+74 (74) in font BXCJIM+LuxiSansRegularRegular
# Feb 11, 2020 2:58:21 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+3 (3) in font BXCJIM+LuxiSansRegularRegular
# Feb 11, 2020 2:58:21 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+86 (86) in font BXCJIM+LuxiSansRegularRegular
# Feb 11, 2020 2:58:21 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+53 (53) in font BXCJIM+LuxiSansRegularRegular
# Feb 11, 2020 2:58:21 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+76 (76) in font BXCJIM+LuxiSansRegularRegular
# Feb 11, 2020 2:58:21 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+70 (70) in font BXCJIM+LuxiSansRegularRegular
# Feb 11, 2020 2:58:21 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+87 (87) in font BXCJIM+LuxiSansRegularRegular
# Feb 11, 2020 2:58:21 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+37 (37) in font BXCJIM+LuxiSansRegularRegular
# Feb 11, 2020 2:58:21 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+17 (17) in font BXCJIM+LuxiSansRegularRegular
# Feb 11, 2020 2:58:21 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+29 (29) in font BXCJIM+LuxiSansRegularRegular
# Feb 11, 2020 2:58:21 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+22 (22) in font BXCJIM+LuxiSansRegularRegular
# Feb 11, 2020 2:58:21 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+27 (27) in font BXCJIM+LuxiSansRegularRegular
# Feb 11, 2020 2:58:21 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+25 (25) in font BXCJIM+LuxiSansRegularRegular
# Feb 11, 2020 2:58:21 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+20 (20) in font BXCJIM+LuxiSansRegularRegular
# Feb 11, 2020 2:58:21 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+28 (28) in font BXCJIM+LuxiSansRegularRegular
# Feb 11, 2020 2:58:21 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+21 (21) in font BXCJIM+LuxiSansRegularRegular
# Feb 11, 2020 2:58:21 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+23 (23) in font BXCJIM+LuxiSansRegularRegular
# Feb 11, 2020 2:58:22 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+24 (24) in font BXCJIM+LuxiSansRegularRegular
# Feb 11, 2020 2:58:22 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+45 (45) in font BXCJIM+LuxiSansRegularRegular
# Feb 11, 2020 2:58:22 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+83 (83) in font BXCJIM+LuxiSansRegularRegular
# Feb 11, 2020 2:58:22 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+69 (69) in font BXCJIM+LuxiSansRegularRegular
# Feb 11, 2020 2:58:22 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+92 (92) in font BXCJIM+LuxiSansRegularRegular
# Feb 11, 2020 2:58:22 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+15 (15) in font BXCJIM+LuxiSansRegularRegular
# Feb 11, 2020 2:58:22 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+36 (36) in font BXCJIM+LuxiSansRegularRegular
# Feb 11, 2020 2:58:22 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+16 (16) in font BXCJIM+LuxiSansRegularRegular
# Feb 11, 2020 2:58:22 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+89 (89) in font BXCJIM+LuxiSansRegularRegular
# Feb 11, 2020 2:58:22 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+19 (19) in font BXCJIM+LuxiSansRegularRegular
# Feb 11, 2020 2:58:22 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+26 (26) in font BXCJIM+LuxiSansRegularRegular
# Feb 11, 2020 2:58:22 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+39 (39) in font BXCJIM+LuxiSansRegularRegular
# Feb 11, 2020 2:58:22 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+51 (51) in font BXCJIM+LuxiSansRegularRegular
# Feb 11, 2020 2:58:22 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+41 (41) in font BXCJIM+LuxiSansRegularRegular
# Feb 11, 2020 2:58:22 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+78 (78) in font BXCJIM+LuxiSansRegularRegular
# Feb 11, 2020 2:58:22 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+82 (82) in font BXCJIM+LuxiSansRegularRegular
# Feb 11, 2020 2:58:22 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+90 (90) in font BXCJIM+LuxiSansRegularRegular
# Feb 11, 2020 2:58:24 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JBIG2 image: jbig2-imageio is not installed
# Feb 11, 2020 2:58:25 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JBIG2 image: jbig2-imageio is not installed
# Feb 11, 2020 2:58:27 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JBIG2 image: jbig2-imageio is not installed
# Feb 11, 2020 2:58:27 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JBIG2 image: jbig2-imageio is not installed
# Feb 11, 2020 2:58:28 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JBIG2 image: jbig2-imageio is not installed
# Feb 11, 2020 2:58:28 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JBIG2 image: jbig2-imageio is not installed
# Feb 11, 2020 2:58:29 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JBIG2 image: jbig2-imageio is not installed
# Feb 11, 2020 2:58:29 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JBIG2 image: jbig2-imageio is not installed

# %%
df[0].shape
# Out:
# (45, 2)

# %%
df[0]
# Out:
#    3. über die Änderungsanträge Müller (Frauken) und Genossen — Nr. 943 der Drucksachen — und Ronneburg,  \
# 0   Koch-Weser und Genossen — Nr. 1037 der Drucksa...
# 1   beantragten Entwurfs eines Gesetzes zur Änderu...
# 2   4. über den Änderungsantrag Ronneburg, Koch-We...
# 3   zur zweiten Beratung des vom 11. Ausschuß bean...
# 4           schutzordnnng — Nr. 928 der Drucksachen —
# 5   5. über den handschriftlichen Antrag Henning u...
# 6   Entwurfs eines Gesetzes zur Änderung der Bacht...
# 7                                                 NaN
# 8                                                Name
# 9                                                 NaN
# 10                            Adams .................
# 11                       Frau Agnes... .. .. . .. . .
# 12                          Albrecht.................
# 13                        Allekotte .................
# 14                          Alpers...................
# 15                          Andre ...................
# 16                        Frau Ansorge... . .. . .. .
# 17                             Frau Arendsee..... ...
# 18                          Frau Arni,lg..... .. .. .
# 19                          Allfhäuscr...............
# 20                                                NaN
# 21                                                NaN
# 22                              Wachmann.............
# 23                           Bachmeier...............
# 24                              Baecker (Berlin) ....
# 25                         Bader.....................
# 26                          Frau Bartels.... .. .. ..
# 27                             Dr. Barth.............
# 28                           Bartschat...............
# 29                                Frau Dr. Bäunier ..
# 30                                Dr. Bayersdörfer...
# 31                           Bazille.................
# 32                         Beck (Oppeln).... .. .. ..
# 33                               Becker (Arnsberg)...
# 34                             Dr. Becker (Hessen). .
# 35                               Becker (Herborn)....
# 36                                   Frau Dr. Beym...
# 37                           Behrens.................
# 38                                Beier (Dresden)....
# 39                          Dr. Bell.................
# 40                          Bender...................
# 41                               Dr. Bergsträßer ....
# 42                      Berudt..... .... .... .... ..
# 43                           Bernstein...............
# 44                               Graf v. Bernstorff..
#
#                                            Unnamed: 0
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                       l. l 2. ! 4. 5. i. 2. 3 4. 5.
# 8                                                Name
# 9                               Abstimmung Abstimmung
# 10  Za Nein Nein Nein Za Bertz ......................
# 11  krank krank krank krank krank Dr. Best...........
# 12  — — — — - - Dr. Bensch............. Za Plein P...
# 13  — Nein Nein Nein Nein Beythien...................
# 14  krank krank krank krank krank Bickes......... ...
# 15  Za Nein Nein Za Plein Bimer... . . .. . . .. ....
# 16  Nein Za Ja Za Nein Biester................... ...
# 17  Nein Za Ja Za . - Fürst Bismarck.... .. .. Za ...
# 18  Nein Za Ja ! Za Nein Blum........................
# 19  Nein Za Ja Za Nein Bock..........................
# 20  Dr. Bockius........... Za i Plein ^ Plein Za Nein
# 21  Bohla..................... krank krank krank k...
# 22  Za ! Nein Nein - Plein Za Frau Bvbul-Schnch . ...
# 23  - - ! — - ^ Bolz.. .. . ..... .... ... ... .. ...
# 24  — Nein Nein Nein Za Bornefeld-Ettmaim.. Za Ple...
# 25  Nein Za Za Za Borrmaim............. Nein Nein ...
# 26  — Bossen................... krank krank krank ...
# 27     Za Nein Nein Nein Za Braun (Düsseldorf) . Nein
# 28  Nein Ha Za Za Nein Dr. Braun (Franken) Plein Z...
# 29          Nein Za Za ! Za Nein Dr. Brauns (München-
# 30  Za Nein Nein ^ Plein Za Gladbach) ... . .. . ....
# 31  — — - - D. Dr. Dr. Brcdt... Za i Plein Nein Ne...
# 32  --  ^ Nein Nein Nein Za Dr. Breitscheid..........
# 33  Za Nein Nein Za Nein Brekelbaum ........... Za...
# 34  Za Nein Nein Nein Za Brev .......................
# 35  Nein Za Za Za ! Plein Brodauf....................
# 36  krank krank krank krank ^ krank Brühn............
# 37  Za Nein Nein Za Za Dr. Brüning.... .. . .. . Z...
# 38  Nein Nein Plein! Brüninghans......... Za Nein ...
# 39  Za Nein - Nein Plein Nein Buchholz...............
# 40         Nein Za Za Za Nein Bttchlnaim.............
# 41  Nein! Za Ja Za ! Nein Bilchwiß...................
# 42  Za ! Nein Nein Nein Za Budjuhn...................
# 43  Nein Ja Ja Za ^ Plein Bütt.......................
# 44  Nein l Za Za Za ! Nein Bülow .... ... ... ... ...

# %%
df[3].shape
df[2]
# Out:
#                          Unnamed: 0 Unnamed: 1  \
# 0        Dr. Hugo..................      krank
# 1    Huke .........................         Za
# 2   Hülser.........................         Za
# 3                Dr.-Ing. Hummel...          —
# 4    Hünlich.......................       Nein
# 5        Husemauu..................       Nein
# 6        Hüttmann..................       Nein
# 7                               NaN        NaN
# 8       Jmbusch....................      krank
# 9                               NaN        NaN
# 10   Jäcker .......................          —
# 11        Jacobshagen..............       Nein
# 12      Jadasch....................       Nein
# 13      Jandrey....................          —
# 14     Janschek....................       Nein
# 15    Janson.......................      krank
# 16  Joos...........................         Za
# 17                              NaN        NaN
# 18       Dr. Jöriffen..............         Za
# 19          Frau Juchacz...........       Nein
# 20  Julier.........................          —
# 21   Junke.........................       Nein
# 22                              NaN        NaN
# 23                              NaN        NaN
# 24              Dr. Kaas (Trier)...         Za
# 25        v. Dr. Kahl..............     beurl.
# 26      Dr. Kalle..................         Za
# 27      Kaltenecker................         Za
# 28      v. Kardorff................        NaN
# 29   Karsten.......................     beurl.
# ..                              ...        ...
# 49       Dr. Klöckner..............         Za
# 50                              NaN        NaN
# 51              Dr.-Ing. Klönne....        NaN
# 52                              NaN        NaN
# 53   Knoll.........................         Za
# 54                              NaN        NaN
# 55             Koch (Düffeldorf)...         Za
# 56       Koch (Essen)..............         Za
# 57       Koch-Weser................       Nein
# 58    Koenen.......................          —
# 59            Koenig (Düsseldorf) .          —
# 60                              NaN        NaN
# 61             König (Westfalen)...          —
# 62                              NaN        NaN
# 63   Kopsch .......................       Nein
# 64                              NaN        NaN
# 65  Korell.........................    entsch.
# 66                              NaN        NaN
# 67    Körner.......................         Za
# 68                              NaN        NaN
# 69       Dr. Korsch................        NaN
# 70                              NaN        NaN
# 71  Kotzke.........................          —
# 72                              NaN        NaN
# 73   Krätzig.......................       Nein
# 74             Kröger (Rostock)....       Nein
# 75             Krüger (Merseburg) .       Nein
# 76  Kube...........................       Nein
# 77   Kuhnt.........................       Nein
# 78             Dr. Kulenkampff-----          —
#
#                          Abstimmung                       Unnamed: 2  \
# 0           krank krank krank krank     Dr. Külz....................
# 1                 Nein Nein Za Nein     Künstler....................
# 2                   Nein Nein Za Za                              NaN
# 3                           — — — —      Lambach....................
# 4                     Za Za Za Nein       Lammers ..................
# 5                     Za Za Za Nein      Landsberg..................
# 6                     Za Za Za Nein   Lang .........................
# 7                               NaN                Frau Lang-Brumann
# 8           krank krank krank krank               Lange-Hegermann...
# 9                               NaN     Laufkötter..................
# 10                 ------ . — — - -      Laverrenz..................
# 11                 NeinZa Za ZaNein     I)r. Leber..................
# 12                    Za Za Za Nein  Leicht.........................
# 13                Nein Nein Nein Za             Dr. Lejeune-Jung ...
# 14                    Za Za Za Nein    Lemmer.......................
# 15          krank krank krank krank   Leopold.......................
# 16                 Nein Nein ZaNein            Graf v. Lerchenfeld..
# 17                              NaN                              NaN
# 18                Nein Nein Nein Za       Leutheußer................
# 19                       — — ZaNein     Dr. Levi....................
# 20                          — — — —     Limbertz....................
# 21                NeinZa Za Za Nein  Lind...........................
# 22                              NaN            v. Lindeiner-Wildau .
# 23                              NaN    Lipinski ....................
# 24              Nein Nein Nein Nein  Löbe...........................
# 25      beurl. beurl. beurl. beurl.              Logemann (Hannover)
# 26                Nein Nein Nein Za              Lohmann (Altona) ..
# 27                Nein Nein Nein Za  Loibl ....... .................
# 28                            — — —          Dr. Löwenstein.........
# 29      beurl. beurl. beurl. beurl.                              NaN
# ..                              ...                              ...
# 49              Nein Nein Nein Nein                              NaN
# 50                              NaN              Graf v. Merveldt...
# 51                Nein Nein Nein Za                              NaN
# 52                              NaN          Meyer (Berlin).........
# 53                Nein Nein Za Nein                              NaN
# 54                              NaN              Meyer (Franken)....
# 55                   Nein NeinZa Za                              NaN
# 56                 Nein NeinZa Nein              Meyer (Hannover) ..
# 57                     Za Za ZaNein              Dr. Mittelmann ....
# 58                           - -- —            Dr. Moldenhauer . - -
# 59                          — — — —      Mollath....................
# 60                              NaN      Morath ....................
# 61                    Za Za Za Nein                              NaN
# 62                              NaN        Or. Moses................
# 63                    Za Za Za Nein                              NaN
# 64                              NaN       Dr. Most..................
# 65  entsch. entsch. entsch. entsch.                              NaN
# 66                              NaN             Müller (Franken) ...
# 67                 Nein Nein NeinZa                              NaN
# 68                              NaN             Frau Mueller-Otfried
# 69                            — — —                              NaN
# 70                              NaN          D. Mumm................
# 71                         — —- — —                              NaN
# 72                              NaN         Münzenberg..............
# 73                    Za Za Za Nein                              NaN
# 74                    Za Za Za Nein                              NaN
# 75                    Za Za Za Nein           Neddermeyer...........
# 76                Nein Nein Nein Za        Frau Nemitz..............
# 77                    Za Za Za Nein       Neubauer..................
# 78                               Za           Neuhaus (Düss eldorf).
#
#    Unnamed: 3          Abstimmung.1 Unnamed: 4
# 0         NaN                     -        NaN
# 1        Nein              Za Za Za       Nein
# 2         NaN                   NaN        NaN
# 3           —                 — — —        NaN
# 4         NaN                   NaN        NaN
# 5        Nein              Za Za Za    , Stein
# 6          Za        Nein Nein Nein         Za
# 7          Za        Nein Nein Nein         Za
# 8         NaN                 — — —         —-
# 9        Nein              Za Za Za       Nein
# 10         Za      Stein Stein Nein         Za
# 11        NaN                — — Ja        NaN
# 12         Za        Nein Nein Nein         Za
# 13         Za       Nein Stein Nein         Za
# 14          —                 — — —          —
# 15         Za        Nein Nein Nein         Za
# 16          —                 — — —          —
# 17        NaN                     —        NaN
# 18          —                  — -—          —
# 19          —                  —— —          —
# 20       Nein              Za Za Za       Nein
# 21         Za             Nein Nein         Za
# 22         Za        Nein Nein Nein         Za
# 23       Nein              Za Za Za       Nein
# 24       Nein              Za Za Za       Nein
# 25         Za        Nein Nein Nein         Za
# 26         Za        Nein Nein Nein         Za
# 27         Za        Nein Nein Nein         Za
# 28       Nein              Za Za Za       Nein
# 29        NaN                   NaN        NaN
# ..        ...                   ...        ...
# 49         Za                   NaN         Za
# 50        NaN                 — — —        NaN
# 51        NaN                   NaN        NaN
# 52       Nein                   NaN       Nein
# 53        NaN              Za Za Za        NaN
# 54       Nein                   NaN       Nein
# 55        NaN              Za Za Za        NaN
# 56         Za        Nein Nein Nein         Za
# 57         Za        Nein Nein Nein         Za
# 58         Za        Nein Nein Nein         Za
# 59         Za        Nein Nein Nein         Za
# 60        NaN        Nein Nein Nein        NaN
# 61         Za                   NaN         Za
# 62       Nein                   NaN       Nein
# 63        NaN              Za Za Za        NaN
# 64          —                 — — —          —
# 65        NaN                   NaN        NaN
# 66       Nein                   NaN       Nein
# 67        NaN              Za Za Za        NaN
# 68     beurl.  beurl. beurl. beurl.     beurl.
# 69        NaN                   NaN        NaN
# 70          —                — —— —        NaN
# 71        NaN                   NaN        NaN
# 72       Nein                     —        - -
# 73        NaN                 Za Za        NaN
# 74        NaN                   NaN        NaN
# 75        NaN                   — —          —
# 76       Nein              Za Za Za       Nein
# 77       Nein              Za Za Za       Nein
# 78      krank     krank krank krank      krank
#
# [79 rows x 7 columns]

# %%
df[3].shape
df[3]
# Out:
#                Frau Neuhaus (West-                    Unnamed: 0  \
# 0       falen) ...................                            Za
# 1         Neumann.................                            Za
# 2     Neyses......................                           NaN
# 3        Nientimp.................                            —-
# 4     Nolte . ^...................  Schaffner.................Za
# 5      Nowack.....................                       entsch.
# 6                              NaN                           NaN
# 7                              NaN                           NaN
# 8        Obendiek.................                           NaN
# 9                              NaN                           NaN
# 10                             NaN                           NaN
# 11         Dr. Oberfohren.........                        NeinZa
# 12   Ohler........................                            Za
# 13                             NaN                           NaN
# 14     Paeth .....................                            Za
# 15     Paffehl ...................                          Nein
# 16   Peine........................                             —
# 17            Pennemann...........                             —
# 18        Dr. Perlitius...........                            Za
# 19     Peters.....................                             —
# 20    Petzold.....................                            Za
# 21      Dr. Pfeffer...............                             —
# 22   Pfeiffer.....................                             -
# 23      Dr. Pfleger...............                        beurl.
# 24       Frau Pfülf...............                          Nein
# 25        Dr. Philipp.............                            Za
# 26         Dr. vr. Preyer.........                            Za
# 27  Putz..........................                          Nein
# 28                             NaN                           NaN
# 29                             NaN                           NaN
# ..                             ...                           ...
# 38                             NaN                           NaN
# 39        Dr. Raschig.............                             —
# 40                             NaN                           NaN
# 41              Rauch (München)...                            Za
# 42        v. Raumer...............                             —
# 43                             NaN                           NaN
# 44       Dr. Reichert.............                            Za
# 45        Frau Reitze.............                          Nein
# 46       Remmele..................                             —
# 47                             NaN                           NaN
# 48             Graf zu Reventlow..                          Nein
# 49           Frhr. v. Rheinbaben..                            Za
# 50        Rheinländer.............                            Za
# 51    Richter.....................                        beurl.
# 52                             NaN                           NaN
# 53             Frhr. v. Richthofen                           NaN
# 54                             NaN                           NaN
# 55          (Breslau).............                            Za
# 56             Frhr. v. Richthofen                           NaN
# 57           (Hannover)...........                             —
# 58      Rieseberg.................                            Za
# 59       Dr. Rießer...............                            Za
# 60     Nippel.....................                             —
# 61              Röder (Baden) ....                         krank
# 62             Röder (Franken) . .                            Za
# 63        Rönneburg...............                          Nein
# 64        Rosenbaum...............                             —
# 65          Dr. Rosenberg.........                             —
# 66        Dr. Rosenfeld...........                          Nein
# 67       Dr. Roß..................                            Za
#
#                             Sachs - Ja  \
# 0                              Saenger
# 1                         Saupe . Nein
# 2                                  NaN
# 3                                  NaN
# 4                                 Nein
# 5          Frau Scheidet........... Za
# 6       Scheidemann............. krank
# 7                  Dr. Schetter.......
# 8                                  NaN
# 9                                   Za
# 10       Schiele .....................
# 11            Frau Schiffgens.... Nein
# 12          Schiller (Hannover).. Nein
# 13        Frau Schilling......... Nein
# 14                Schirmer (Dresden)..
# 15             Schirmer (Franken).. Za
# 16        Schlack.....................
# 17             Schlagewerth...........
# 18       Schlange ................. Za
# 19         Schlecht...................
# 20  Schlicke..................... Nein
# 21    Schlüter................... Nein
# 22           Schmidt (Berlin) ... Nein
# 23                Schmidt (Cöpenick)..
# 24              Schmidt (Hannover). Za
# 25               Schmidt (Hirschberg).
# 26                 Schmidt (Meißen)...
# 27            Schmidt (Stettin). -. Za
# 28      Schnabrich............... Nein
# 29                                 NaN
# ..                                 ...
# 38                                 NaN
# 39   Schneller................... Nein
# 40                                 NaN
# 41          Scholem...................
# 42           Dr. Scholz...............
# 43                                 NaN
# 44     Schöpflin................. Nein
# 45         Frau Schott............. Za
# 46        Schreck.....................
# 47                                 NaN
# 48            I). Dr. Schreiber ... Za
# 49                  Schröder (Mecklen­
# 50     burg) ................... krank
# 51                      Frau Schroeder
# 52                                 NaN
# 53           (Schleswig-Holstein) Nein
# 54                                 NaN
# 55           Schröter (Liegnitz)... Za
# 56       Dr. Schücking........... Nein
# 57               Schuldt (Steglitz)...
# 58           Graf v. d. Schulenburg Za
# 59             Schulte (Breslau)... 2«
# 60             Schultz (Bromberg).. Za
# 61          Schulz (Brechen)----- Nein
# 62               Schulz-Gahmen........
# 63           Schulz (Königsberg). Nein
# 64          Frau Schulz (Wests.). Nein
# 65            Schulze (Frankfurt).. Za
# 66                Schumann (Frankfurt)
# 67                Schumann (Stettin) .
#
#                                  Schwarz (Frankfurt). Unnamed: 1
# 0                                    Schwarzer (Ober­        NaN
# 1                                   bayern) .........        NaN
# 2                                                 NaN        NaN
# 3                       Seger........................      krank
# 4                       Seibert......................      krank
# 5                       Seidel.......................       Nein
# 6                        Seiffert ...................        NaN
# 7                                                 NaN        NaN
# 8                                                 NaN        NaN
# 9                              Frau Sender...........       Nein
# 10                                                NaN        NaN
# 11                        Seppel.....................        NaN
# 12  Severing.................Seydewitz...............  krankNein
# 13                           Silberschmidt...........       Nein
# 14                               Silier (Württemberg)    entsch.
# 15                                Simon (Franken) ...       Nein
# 16                                 Simon (Schwaben)..       Nein
# 17                       Sinn........................        NaN
# 18                          Sollmann.................       Nein
# 19                       Sonner......................        NaN
# 20                                Dr.-Jng. Sorge ....   Zabeurl.
# 21                               Dr. Spahn (Berlin)..        NaN
# 22                                Dr. Spahn (Köln) ..        NaN
# 23                        Sparrer....................       Nein
# 24                                Frau v. Sperber....        NaN
# 25                          Dr. Spuler...............         Za
# 26                                                NaN        NaN
# 27                         Staab.....................       Nein
# 28                                                NaN        NaN
# 29                          Stampfer.................        NaN
# ..                                                ...        ...
# 38                         Steinkopf.................       Nein
# 39                                                NaN        NaN
# 40                               Stelling (Oppeln)...       Nein
# 41                        Stoecker...................       Nein
# 42                                                NaN        NaN
# 43                      Stöhr........................     beurl.
# 44                         Straßer...................      krank
# 45                                 D. Strathmann-----        NaN
# 46                                                NaN        NaN
# 47                        Strauß.....................        NaN
# 48                                Dr. Stresemann ....         Za
# 49                       Ströbel.....................       Nein
# 50                      Strötzel.....................       Nein
# 51                                                NaN        NaN
# 52                            Stubbendorff...........        NaN
# 53                                                NaN        NaN
# 54                        Stücklen...................       Nein
# 55                                                NaN        NaN
# 56                                                NaN        NaN
# 57                          Taubadel.................       Nein
# 58                           Frau Teusch.............         Za
# 59                         Thabor ...................      krank
# 60                            Thälmann...............        NaN
# 61                       Thiel . ^...................         Za
# 62                         Thomsen...................         Za
# 63                        v. Tirpitz.................        NaN
# 64                       Torgler.....................       Nein
# 65                         Tremmel...................         Za
# 66                          Treviranus...............        NaN
# 67                                Troßmann (Nürnberg)        NaN
#
# [68 rows x 5 columns]

# %%
df[3].shape
df[3]
# Out:
#                Frau Neuhaus (West-                    Unnamed: 0  \
# 0       falen) ...................                            Za
# 1         Neumann.................                            Za
# 2     Neyses......................                           NaN
# 3        Nientimp.................                            —-
# 4     Nolte . ^...................  Schaffner.................Za
# 5      Nowack.....................                       entsch.
# 6                              NaN                           NaN
# 7                              NaN                           NaN
# 8        Obendiek.................                           NaN
# 9                              NaN                           NaN
# 10                             NaN                           NaN
# 11         Dr. Oberfohren.........                        NeinZa
# 12   Ohler........................                            Za
# 13                             NaN                           NaN
# 14     Paeth .....................                            Za
# 15     Paffehl ...................                          Nein
# 16   Peine........................                             —
# 17            Pennemann...........                             —
# 18        Dr. Perlitius...........                            Za
# 19     Peters.....................                             —
# 20    Petzold.....................                            Za
# 21      Dr. Pfeffer...............                             —
# 22   Pfeiffer.....................                             -
# 23      Dr. Pfleger...............                        beurl.
# 24       Frau Pfülf...............                          Nein
# 25        Dr. Philipp.............                            Za
# 26         Dr. vr. Preyer.........                            Za
# 27  Putz..........................                          Nein
# 28                             NaN                           NaN
# 29                             NaN                           NaN
# ..                             ...                           ...
# 38                             NaN                           NaN
# 39        Dr. Raschig.............                             —
# 40                             NaN                           NaN
# 41              Rauch (München)...                            Za
# 42        v. Raumer...............                             —
# 43                             NaN                           NaN
# 44       Dr. Reichert.............                            Za
# 45        Frau Reitze.............                          Nein
# 46       Remmele..................                             —
# 47                             NaN                           NaN
# 48             Graf zu Reventlow..                          Nein
# 49           Frhr. v. Rheinbaben..                            Za
# 50        Rheinländer.............                            Za
# 51    Richter.....................                        beurl.
# 52                             NaN                           NaN
# 53             Frhr. v. Richthofen                           NaN
# 54                             NaN                           NaN
# 55          (Breslau).............                            Za
# 56             Frhr. v. Richthofen                           NaN
# 57           (Hannover)...........                             —
# 58      Rieseberg.................                            Za
# 59       Dr. Rießer...............                            Za
# 60     Nippel.....................                             —
# 61              Röder (Baden) ....                         krank
# 62             Röder (Franken) . .                            Za
# 63        Rönneburg...............                          Nein
# 64        Rosenbaum...............                             —
# 65          Dr. Rosenberg.........                             —
# 66        Dr. Rosenfeld...........                          Nein
# 67       Dr. Roß..................                            Za
#
#                             Sachs - Ja  \
# 0                              Saenger
# 1                         Saupe . Nein
# 2                                  NaN
# 3                                  NaN
# 4                                 Nein
# 5          Frau Scheidet........... Za
# 6       Scheidemann............. krank
# 7                  Dr. Schetter.......
# 8                                  NaN
# 9                                   Za
# 10       Schiele .....................
# 11            Frau Schiffgens.... Nein
# 12          Schiller (Hannover).. Nein
# 13        Frau Schilling......... Nein
# 14                Schirmer (Dresden)..
# 15             Schirmer (Franken).. Za
# 16        Schlack.....................
# 17             Schlagewerth...........
# 18       Schlange ................. Za
# 19         Schlecht...................
# 20  Schlicke..................... Nein
# 21    Schlüter................... Nein
# 22           Schmidt (Berlin) ... Nein
# 23                Schmidt (Cöpenick)..
# 24              Schmidt (Hannover). Za
# 25               Schmidt (Hirschberg).
# 26                 Schmidt (Meißen)...
# 27            Schmidt (Stettin). -. Za
# 28      Schnabrich............... Nein
# 29                                 NaN
# ..                                 ...
# 38                                 NaN
# 39   Schneller................... Nein
# 40                                 NaN
# 41          Scholem...................
# 42           Dr. Scholz...............
# 43                                 NaN
# 44     Schöpflin................. Nein
# 45         Frau Schott............. Za
# 46        Schreck.....................
# 47                                 NaN
# 48            I). Dr. Schreiber ... Za
# 49                  Schröder (Mecklen­
# 50     burg) ................... krank
# 51                      Frau Schroeder
# 52                                 NaN
# 53           (Schleswig-Holstein) Nein
# 54                                 NaN
# 55           Schröter (Liegnitz)... Za
# 56       Dr. Schücking........... Nein
# 57               Schuldt (Steglitz)...
# 58           Graf v. d. Schulenburg Za
# 59             Schulte (Breslau)... 2«
# 60             Schultz (Bromberg).. Za
# 61          Schulz (Brechen)----- Nein
# 62               Schulz-Gahmen........
# 63           Schulz (Königsberg). Nein
# 64          Frau Schulz (Wests.). Nein
# 65            Schulze (Frankfurt).. Za
# 66                Schumann (Frankfurt)
# 67                Schumann (Stettin) .
#
#                                  Schwarz (Frankfurt). Unnamed: 1
# 0                                    Schwarzer (Ober­        NaN
# 1                                   bayern) .........        NaN
# 2                                                 NaN        NaN
# 3                       Seger........................      krank
# 4                       Seibert......................      krank
# 5                       Seidel.......................       Nein
# 6                        Seiffert ...................        NaN
# 7                                                 NaN        NaN
# 8                                                 NaN        NaN
# 9                              Frau Sender...........       Nein
# 10                                                NaN        NaN
# 11                        Seppel.....................        NaN
# 12  Severing.................Seydewitz...............  krankNein
# 13                           Silberschmidt...........       Nein
# 14                               Silier (Württemberg)    entsch.
# 15                                Simon (Franken) ...       Nein
# 16                                 Simon (Schwaben)..       Nein
# 17                       Sinn........................        NaN
# 18                          Sollmann.................       Nein
# 19                       Sonner......................        NaN
# 20                                Dr.-Jng. Sorge ....   Zabeurl.
# 21                               Dr. Spahn (Berlin)..        NaN
# 22                                Dr. Spahn (Köln) ..        NaN
# 23                        Sparrer....................       Nein
# 24                                Frau v. Sperber....        NaN
# 25                          Dr. Spuler...............         Za
# 26                                                NaN        NaN
# 27                         Staab.....................       Nein
# 28                                                NaN        NaN
# 29                          Stampfer.................        NaN
# ..                                                ...        ...
# 38                         Steinkopf.................       Nein
# 39                                                NaN        NaN
# 40                               Stelling (Oppeln)...       Nein
# 41                        Stoecker...................       Nein
# 42                                                NaN        NaN
# 43                      Stöhr........................     beurl.
# 44                         Straßer...................      krank
# 45                                 D. Strathmann-----        NaN
# 46                                                NaN        NaN
# 47                        Strauß.....................        NaN
# 48                                Dr. Stresemann ....         Za
# 49                       Ströbel.....................       Nein
# 50                      Strötzel.....................       Nein
# 51                                                NaN        NaN
# 52                            Stubbendorff...........        NaN
# 53                                                NaN        NaN
# 54                        Stücklen...................       Nein
# 55                                                NaN        NaN
# 56                                                NaN        NaN
# 57                          Taubadel.................       Nein
# 58                           Frau Teusch.............         Za
# 59                         Thabor ...................      krank
# 60                            Thälmann...............        NaN
# 61                       Thiel . ^...................         Za
# 62                         Thomsen...................         Za
# 63                        v. Tirpitz.................        NaN
# 64                       Torgler.....................       Nein
# 65                         Tremmel...................         Za
# 66                          Treviranus...............        NaN
# 67                                Troßmann (Nürnberg)        NaN
#
# [68 rows x 5 columns]

# %%
li = df[3].values.tolist()

# %%
len(li)
li[0][0]
#type(li[0][0])
# Out:
# 'falen) ...................'

# %%
import re
import math
def processRow(val):
    new_val = []
    print("Entire array: ",val)
    for i in val:
        print((i))
        
        #check if the value is nan
        if isinstance(i, float) and math.isnan(i):
            #print("Nan value")
            new_val.append("-")
            continue
            
        #replacing all the dots with space
        replace_dot = re.sub('[.]{2,}',"#$",i) #i.replace('.', '#')
        #replace close bracket
        replace_brac = re.sub("\)",")#$",replace_dot)
        #convert multiple whitespaces into single whitespace
        white_rem = replace_brac#re.sub('#+',"#$",replace_dot)
        #print(white_rem+" "+str(len(white_rem)))
        
        new_val.append(white_rem)
    print(new_val," ",str(len(new_val)))
    return new_val
arr_list =[]
for i in range(0,len(li)):        
    arr_list.append(processRow(li[i]))
# Out:
# Entire array:  ['falen) ...................', 'Za', 'Saenger', 'Schwarzer (Ober\xad', nan]
# falen) ...................
# Za
# Saenger
# Schwarzer (Ober­
# nan
# ['falen)#$ #$', 'Za', 'Saenger', 'Schwarzer (Ober\xad', '-']   5
# Entire array:  ['Neumann.................', 'Za', 'Saupe . Nein', 'bayern) .........', nan]
# Neumann.................
# Za
# Saupe . Nein
# bayern) .........
# nan
# ['Neumann#$', 'Za', 'Saupe . Nein', 'bayern)#$ #$', '-']   5
# Entire array:  ['Neyses......................', nan, nan, nan, nan]
# Neyses......................
# nan
# nan
# nan
# nan
# ['Neyses#$', '-', '-', '-', '-']   5
# Entire array:  ['Nientimp.................', '—-', nan, 'Seger........................', 'krank']
# Nientimp.................
# —-
# nan
# Seger........................
# krank
# ['Nientimp#$', '—-', '-', 'Seger#$', 'krank']   5
# Entire array:  ['Nolte . ^...................', 'Schaffner.................Za', 'Nein', 'Seibert......................', 'krank']
# Nolte . ^...................
# Schaffner.................Za
# Nein
# Seibert......................
# krank
# ['Nolte . ^#$', 'Schaffner#$Za', 'Nein', 'Seibert#$', 'krank']   5
# Entire array:  ['Nowack.....................', 'entsch.', 'Frau Scheidet........... Za', 'Seidel.......................', 'Nein']
# Nowack.....................
# entsch.
# Frau Scheidet........... Za
# Seidel.......................
# Nein
# ['Nowack#$', 'entsch.', 'Frau Scheidet#$ Za', 'Seidel#$', 'Nein']   5
# Entire array:  [nan, nan, 'Scheidemann............. krank', 'Seiffert ...................', nan]
# nan
# nan
# Scheidemann............. krank
# Seiffert ...................
# nan
# ['-', '-', 'Scheidemann#$ krank', 'Seiffert #$', '-']   5
# Entire array:  [nan, nan, 'Dr. Schetter.......', nan, nan]
# nan
# nan
# Dr. Schetter.......
# nan
# nan
# ['-', '-', 'Dr. Schetter#$', '-', '-']   5
# Entire array:  ['Obendiek.................', nan, nan, nan, nan]
# Obendiek.................
# nan
# nan
# nan
# nan
# ['Obendiek#$', '-', '-', '-', '-']   5
# Entire array:  [nan, nan, 'Za', 'Frau Sender...........', 'Nein']
# nan
# nan
# Za
# Frau Sender...........
# Nein
# ['-', '-', 'Za', 'Frau Sender#$', 'Nein']   5
# Entire array:  [nan, nan, 'Schiele .....................', nan, nan]
# nan
# nan
# Schiele .....................
# nan
# nan
# ['-', '-', 'Schiele #$', '-', '-']   5
# Entire array:  ['Dr. Oberfohren.........', 'NeinZa', 'Frau Schiffgens.... Nein', 'Seppel.....................', nan]
# Dr. Oberfohren.........
# NeinZa
# Frau Schiffgens.... Nein
# Seppel.....................
# nan
# ['Dr. Oberfohren#$', 'NeinZa', 'Frau Schiffgens#$ Nein', 'Seppel#$', '-']   5
# Entire array:  ['Ohler........................', 'Za', 'Schiller (Hannover).. Nein', 'Severing.................Seydewitz.................', 'krankNein']
# Ohler........................
# Za
# Schiller (Hannover).. Nein
# Severing.................Seydewitz.................
# krankNein
# ['Ohler#$', 'Za', 'Schiller (Hannover)#$#$ Nein', 'Severing#$Seydewitz#$', 'krankNein']   5
# Entire array:  [nan, nan, 'Frau Schilling......... Nein', 'Silberschmidt...........', 'Nein']
# nan
# nan
# Frau Schilling......... Nein
# Silberschmidt...........
# Nein
# ['-', '-', 'Frau Schilling#$ Nein', 'Silberschmidt#$', 'Nein']   5
# Entire array:  ['Paeth .....................', 'Za', 'Schirmer (Dresden)..', 'Silier (Württemberg)', 'entsch.']
# Paeth .....................
# Za
# Schirmer (Dresden)..
# Silier (Württemberg)
# entsch.
# ['Paeth #$', 'Za', 'Schirmer (Dresden)#$#$', 'Silier (Württemberg)#$', 'entsch.']   5
# Entire array:  ['Paffehl ...................', 'Nein', 'Schirmer (Franken).. Za', 'Simon (Franken) ...', 'Nein']
# Paffehl ...................
# Nein
# Schirmer (Franken).. Za
# Simon (Franken) ...
# Nein
# ['Paffehl #$', 'Nein', 'Schirmer (Franken)#$#$ Za', 'Simon (Franken)#$ #$', 'Nein']   5
# Entire array:  ['Peine........................', '—', 'Schlack.....................', 'Simon (Schwaben)..', 'Nein']
# Peine........................
# —
# Schlack.....................
# Simon (Schwaben)..
# Nein
# ['Peine#$', '—', 'Schlack#$', 'Simon (Schwaben)#$#$', 'Nein']   5
# Entire array:  ['Pennemann...........', '—', 'Schlagewerth...........', 'Sinn........................', nan]
# Pennemann...........
# —
# Schlagewerth...........
# Sinn........................
# nan
# ['Pennemann#$', '—', 'Schlagewerth#$', 'Sinn#$', '-']   5
# Entire array:  ['Dr. Perlitius...........', 'Za', 'Schlange ................. Za', 'Sollmann.................', 'Nein']
# Dr. Perlitius...........
# Za
# Schlange ................. Za
# Sollmann.................
# Nein
# ['Dr. Perlitius#$', 'Za', 'Schlange #$ Za', 'Sollmann#$', 'Nein']   5
# Entire array:  ['Peters.....................', '—', 'Schlecht...................', 'Sonner......................', nan]
# Peters.....................
# —
# Schlecht...................
# Sonner......................
# nan
# ['Peters#$', '—', 'Schlecht#$', 'Sonner#$', '-']   5
# Entire array:  ['Petzold.....................', 'Za', 'Schlicke..................... Nein', 'Dr.-Jng. Sorge ....', 'Zabeurl.']
# Petzold.....................
# Za
# Schlicke..................... Nein
# Dr.-Jng. Sorge ....
# Zabeurl.
# ['Petzold#$', 'Za', 'Schlicke#$ Nein', 'Dr.-Jng. Sorge #$', 'Zabeurl.']   5
# Entire array:  ['Dr. Pfeffer...............', '—', 'Schlüter................... Nein', 'Dr. Spahn (Berlin)..', nan]
# Dr. Pfeffer...............
# —
# Schlüter................... Nein
# Dr. Spahn (Berlin)..
# nan
# ['Dr. Pfeffer#$', '—', 'Schlüter#$ Nein', 'Dr. Spahn (Berlin)#$#$', '-']   5
# Entire array:  ['Pfeiffer.....................', '-', 'Schmidt (Berlin) ... Nein', 'Dr. Spahn (Köln) ..', nan]
# Pfeiffer.....................
# -
# Schmidt (Berlin) ... Nein
# Dr. Spahn (Köln) ..
# nan
# ['Pfeiffer#$', '-', 'Schmidt (Berlin)#$ #$ Nein', 'Dr. Spahn (Köln)#$ #$', '-']   5
# Entire array:  ['Dr. Pfleger...............', 'beurl.', 'Schmidt (Cöpenick)..', 'Sparrer....................', 'Nein']
# Dr. Pfleger...............
# beurl.
# Schmidt (Cöpenick)..
# Sparrer....................
# Nein
# ['Dr. Pfleger#$', 'beurl.', 'Schmidt (Cöpenick)#$#$', 'Sparrer#$', 'Nein']   5
# Entire array:  ['Frau Pfülf...............', 'Nein', 'Schmidt (Hannover). Za', 'Frau v. Sperber....', nan]
# Frau Pfülf...............
# Nein
# Schmidt (Hannover). Za
# Frau v. Sperber....
# nan
# ['Frau Pfülf#$', 'Nein', 'Schmidt (Hannover)#$. Za', 'Frau v. Sperber#$', '-']   5
# Entire array:  ['Dr. Philipp.............', 'Za', 'Schmidt (Hirschberg).', 'Dr. Spuler...............', 'Za']
# Dr. Philipp.............
# Za
# Schmidt (Hirschberg).
# Dr. Spuler...............
# Za
# ['Dr. Philipp#$', 'Za', 'Schmidt (Hirschberg)#$.', 'Dr. Spuler#$', 'Za']   5
# Entire array:  ['Dr. vr. Preyer.........', 'Za', 'Schmidt (Meißen)...', nan, nan]
# Dr. vr. Preyer.........
# Za
# Schmidt (Meißen)...
# nan
# nan
# ['Dr. vr. Preyer#$', 'Za', 'Schmidt (Meißen)#$#$', '-', '-']   5
# Entire array:  ['Putz..........................', 'Nein', 'Schmidt (Stettin). -. Za', 'Staab.....................', 'Nein']
# Putz..........................
# Nein
# Schmidt (Stettin). -. Za
# Staab.....................
# Nein
# ['Putz#$', 'Nein', 'Schmidt (Stettin)#$. -. Za', 'Staab#$', 'Nein']   5
# Entire array:  [nan, nan, 'Schnabrich............... Nein', nan, nan]
# nan
# nan
# Schnabrich............... Nein
# nan
# nan
# ['-', '-', 'Schnabrich#$ Nein', '-', '-']   5
# Entire array:  [nan, nan, nan, 'Stampfer.................', nan]
# nan
# nan
# nan
# Stampfer.................
# nan
# ['-', '-', '-', 'Stampfer#$', '-']   5
# Entire array:  ['Dr. Duaatz.............', 'Za', 'Dr. Schnee............... beurl.', nan, 'Nein']
# Dr. Duaatz.............
# Za
# Dr. Schnee............... beurl.
# nan
# Nein
# ['Dr. Duaatz#$', 'Za', 'Dr. Schnee#$ beurl.', '-', 'Nein']   5
# Entire array:  ['Dr. Quessel...............', 'Frhr. v. StauffenbergNein', 'Schneider (Berlin) .. Nein', nan, 'Za']
# Dr. Quessel...............
# Frhr. v. StauffenbergNein
# Schneider (Berlin) .. Nein
# nan
# Za
# ['Dr. Quessel#$', 'Frhr. v. StauffenbergNein', 'Schneider (Berlin)#$ #$ Nein', '-', 'Za']   5
# Entire array:  [nan, nan, nan, 'Stegerwald...............', nan]
# nan
# nan
# nan
# Stegerwald...............
# nan
# ['-', '-', '-', 'Stegerwald#$', '-']   5
# Entire array:  [nan, nan, 'Dr. Schneider', nan, 'Za']
# nan
# nan
# Dr. Schneider
# nan
# Za
# ['-', '-', 'Dr. Schneider', '-', 'Za']   5
# Entire array:  [nan, nan, nan, 'Frau Dr. Stegmann.', 'Nein']
# nan
# nan
# nan
# Frau Dr. Stegmann.
# Nein
# ['-', '-', '-', 'Frau Dr. Stegmann.', 'Nein']   5
# Entire array:  ['Rädel.....................', nan, '(Dresden)............. Za', 'Steiger.....................', nan]
# Rädel.....................
# nan
# (Dresden)............. Za
# Steiger.....................
# nan
# ['Rädel#$', '-', '(Dresden)#$#$ Za', 'Steiger#$', '-']   5
# Entire array:  ['Dr. Rademacher ....', 'Za', 'Dr. Schneider', 'Dr. Steiniger...........', nan]
# Dr. Rademacher ....
# Za
# Dr. Schneider
# Dr. Steiniger...........
# nan
# ['Dr. Rademacher #$', 'Za', 'Dr. Schneider', 'Dr. Steiniger#$', '-']   5
# Entire array:  ['v. Ramin.................', '—', '(Thüringen) ........', nan, 'Za']
# v. Ramin.................
# —
# (Thüringen) ........
# nan
# Za
# ['v. Ramin#$', '—', '(Thüringen)#$ #$', '-', 'Za']   5
# Entire array:  [nan, nan, nan, 'Steinkopf.................', 'Nein']
# nan
# nan
# nan
# Steinkopf.................
# Nein
# ['-', '-', '-', 'Steinkopf#$', 'Nein']   5
# Entire array:  ['Dr. Raschig.............', '—', 'Schneller................... Nein', nan, nan]
# Dr. Raschig.............
# —
# Schneller................... Nein
# nan
# nan
# ['Dr. Raschig#$', '—', 'Schneller#$ Nein', '-', '-']   5
# Entire array:  [nan, nan, nan, 'Stelling (Oppeln)...', 'Nein']
# nan
# nan
# nan
# Stelling (Oppeln)...
# Nein
# ['-', '-', '-', 'Stelling (Oppeln)#$#$', 'Nein']   5
# Entire array:  ['Rauch (München)...', 'Za', 'Scholem...................', 'Stoecker...................', 'Nein']
# Rauch (München)...
# Za
# Scholem...................
# Stoecker...................
# Nein
# ['Rauch (München)#$#$', 'Za', 'Scholem#$', 'Stoecker#$', 'Nein']   5
# Entire array:  ['v. Raumer...............', '—', 'Dr. Scholz...............', nan, nan]
# v. Raumer...............
# —
# Dr. Scholz...............
# nan
# nan
# ['v. Raumer#$', '—', 'Dr. Scholz#$', '-', '-']   5
# Entire array:  [nan, nan, nan, 'Stöhr........................', 'beurl.']
# nan
# nan
# nan
# Stöhr........................
# beurl.
# ['-', '-', '-', 'Stöhr#$', 'beurl.']   5
# Entire array:  ['Dr. Reichert.............', 'Za', 'Schöpflin................. Nein', 'Straßer...................', 'krank']
# Dr. Reichert.............
# Za
# Schöpflin................. Nein
# Straßer...................
# krank
# ['Dr. Reichert#$', 'Za', 'Schöpflin#$ Nein', 'Straßer#$', 'krank']   5
# Entire array:  ['Frau Reitze.............', 'Nein', 'Frau Schott............. Za', 'D. Strathmann-----', nan]
# Frau Reitze.............
# Nein
# Frau Schott............. Za
# D. Strathmann-----
# nan
# ['Frau Reitze#$', 'Nein', 'Frau Schott#$ Za', 'D. Strathmann-----', '-']   5
# Entire array:  ['Remmele..................', '—', 'Schreck.....................', nan, nan]
# Remmele..................
# —
# Schreck.....................
# nan
# nan
# ['Remmele#$', '—', 'Schreck#$', '-', '-']   5
# Entire array:  [nan, nan, nan, 'Strauß.....................', nan]
# nan
# nan
# nan
# Strauß.....................
# nan
# ['-', '-', '-', 'Strauß#$', '-']   5
# Entire array:  ['Graf zu Reventlow..', 'Nein', 'I). Dr. Schreiber ... Za', 'Dr. Stresemann ....', 'Za']
# Graf zu Reventlow..
# Nein
# I). Dr. Schreiber ... Za
# Dr. Stresemann ....
# Za
# ['Graf zu Reventlow#$', 'Nein', 'I)#$. Dr. Schreiber #$ Za', 'Dr. Stresemann #$', 'Za']   5
# Entire array:  ['Frhr. v. Rheinbaben..', 'Za', 'Schröder (Mecklen\xad', 'Ströbel.....................', 'Nein']
# Frhr. v. Rheinbaben..
# Za
# Schröder (Mecklen­
# Ströbel.....................
# Nein
# ['Frhr. v. Rheinbaben#$', 'Za', 'Schröder (Mecklen\xad', 'Ströbel#$', 'Nein']   5
# Entire array:  ['Rheinländer.............', 'Za', 'burg) ................... krank', 'Strötzel.....................', 'Nein']
# Rheinländer.............
# Za
# burg) ................... krank
# Strötzel.....................
# Nein
# ['Rheinländer#$', 'Za', 'burg)#$ #$ krank', 'Strötzel#$', 'Nein']   5
# Entire array:  ['Richter.....................', 'beurl.', 'Frau Schroeder', nan, nan]
# Richter.....................
# beurl.
# Frau Schroeder
# nan
# nan
# ['Richter#$', 'beurl.', 'Frau Schroeder', '-', '-']   5
# Entire array:  [nan, nan, nan, 'Stubbendorff...........', nan]
# nan
# nan
# nan
# Stubbendorff...........
# nan
# ['-', '-', '-', 'Stubbendorff#$', '-']   5
# Entire array:  ['Frhr. v. Richthofen', nan, '(Schleswig-Holstein) Nein', nan, nan]
# Frhr. v. Richthofen
# nan
# (Schleswig-Holstein) Nein
# nan
# nan
# ['Frhr. v. Richthofen', '-', '(Schleswig-Holstein)#$ Nein', '-', '-']   5
# Entire array:  [nan, nan, nan, 'Stücklen...................', 'Nein']
# nan
# nan
# nan
# Stücklen...................
# Nein
# ['-', '-', '-', 'Stücklen#$', 'Nein']   5
# Entire array:  ['(Breslau).............', 'Za', 'Schröter (Liegnitz)... Za', nan, nan]
# (Breslau).............
# Za
# Schröter (Liegnitz)... Za
# nan
# nan
# ['(Breslau)#$#$', 'Za', 'Schröter (Liegnitz)#$#$ Za', '-', '-']   5
# Entire array:  ['Frhr. v. Richthofen', nan, 'Dr. Schücking........... Nein', nan, nan]
# Frhr. v. Richthofen
# nan
# Dr. Schücking........... Nein
# nan
# nan
# ['Frhr. v. Richthofen', '-', 'Dr. Schücking#$ Nein', '-', '-']   5
# Entire array:  ['(Hannover)...........', '—', 'Schuldt (Steglitz)...', 'Taubadel.................', 'Nein']
# (Hannover)...........
# —
# Schuldt (Steglitz)...
# Taubadel.................
# Nein
# ['(Hannover)#$#$', '—', 'Schuldt (Steglitz)#$#$', 'Taubadel#$', 'Nein']   5
# Entire array:  ['Rieseberg.................', 'Za', 'Graf v. d. Schulenburg Za', 'Frau Teusch.............', 'Za']
# Rieseberg.................
# Za
# Graf v. d. Schulenburg Za
# Frau Teusch.............
# Za
# ['Rieseberg#$', 'Za', 'Graf v. d. Schulenburg Za', 'Frau Teusch#$', 'Za']   5
# Entire array:  ['Dr. Rießer...............', 'Za', 'Schulte (Breslau)... 2«', 'Thabor ...................', 'krank']
# Dr. Rießer...............
# Za
# Schulte (Breslau)... 2«
# Thabor ...................
# krank
# ['Dr. Rießer#$', 'Za', 'Schulte (Breslau)#$#$ 2«', 'Thabor #$', 'krank']   5
# Entire array:  ['Nippel.....................', '—', 'Schultz (Bromberg).. Za', 'Thälmann...............', nan]
# Nippel.....................
# —
# Schultz (Bromberg).. Za
# Thälmann...............
# nan
# ['Nippel#$', '—', 'Schultz (Bromberg)#$#$ Za', 'Thälmann#$', '-']   5
# Entire array:  ['Röder (Baden) ....', 'krank', 'Schulz (Brechen)----- Nein', 'Thiel . ^...................', 'Za']
# Röder (Baden) ....
# krank
# Schulz (Brechen)----- Nein
# Thiel . ^...................
# Za
# ['Röder (Baden)#$ #$', 'krank', 'Schulz (Brechen)#$----- Nein', 'Thiel . ^#$', 'Za']   5
# Entire array:  ['Röder (Franken) . .', 'Za', 'Schulz-Gahmen........', 'Thomsen...................', 'Za']
# Röder (Franken) . .
# Za
# Schulz-Gahmen........
# Thomsen...................
# Za
# ['Röder (Franken)#$ . .', 'Za', 'Schulz-Gahmen#$', 'Thomsen#$', 'Za']   5
# Entire array:  ['Rönneburg...............', 'Nein', 'Schulz (Königsberg). Nein', 'v. Tirpitz.................', nan]
# Rönneburg...............
# Nein
# Schulz (Königsberg). Nein
# v. Tirpitz.................
# nan
# ['Rönneburg#$', 'Nein', 'Schulz (Königsberg)#$. Nein', 'v. Tirpitz#$', '-']   5
# Entire array:  ['Rosenbaum...............', '—', 'Frau Schulz (Wests.). Nein', 'Torgler.....................', 'Nein']
# Rosenbaum...............
# —
# Frau Schulz (Wests.). Nein
# Torgler.....................
# Nein
# ['Rosenbaum#$', '—', 'Frau Schulz (Wests.)#$. Nein', 'Torgler#$', 'Nein']   5
# Entire array:  ['Dr. Rosenberg.........', '—', 'Schulze (Frankfurt).. Za', 'Tremmel...................', 'Za']
# Dr. Rosenberg.........
# —
# Schulze (Frankfurt).. Za
# Tremmel...................
# Za
# ['Dr. Rosenberg#$', '—', 'Schulze (Frankfurt)#$#$ Za', 'Tremmel#$', 'Za']   5
# Entire array:  ['Dr. Rosenfeld...........', 'Nein', 'Schumann (Frankfurt)', 'Treviranus...............', nan]
# Dr. Rosenfeld...........
# Nein
# Schumann (Frankfurt)
# Treviranus...............
# nan
# ['Dr. Rosenfeld#$', 'Nein', 'Schumann (Frankfurt)#$', 'Treviranus#$', '-']   5
# Entire array:  ['Dr. Roß..................', 'Za', 'Schumann (Stettin) .', 'Troßmann (Nürnberg)', nan]
# Dr. Roß..................
# Za
# Schumann (Stettin) .
# Troßmann (Nürnberg)
# nan
# ['Dr. Roß#$', 'Za', 'Schumann (Stettin)#$ .', 'Troßmann (Nürnberg)#$', '-']   5

# %%
print(len(arr_list))
for i in arr_list:
    print(i)
# Out:
# 68
# ['falen)#$ #$', 'Za', 'Saenger', 'Schwarzer (Ober\xad', '-']
# ['Neumann#$', 'Za', 'Saupe . Nein', 'bayern)#$ #$', '-']
# ['Neyses#$', '-', '-', '-', '-']
# ['Nientimp#$', '—-', '-', 'Seger#$', 'krank']
# ['Nolte . ^#$', 'Schaffner#$Za', 'Nein', 'Seibert#$', 'krank']
# ['Nowack#$', 'entsch.', 'Frau Scheidet#$ Za', 'Seidel#$', 'Nein']
# ['-', '-', 'Scheidemann#$ krank', 'Seiffert #$', '-']
# ['-', '-', 'Dr. Schetter#$', '-', '-']
# ['Obendiek#$', '-', '-', '-', '-']
# ['-', '-', 'Za', 'Frau Sender#$', 'Nein']
# ['-', '-', 'Schiele #$', '-', '-']
# ['Dr. Oberfohren#$', 'NeinZa', 'Frau Schiffgens#$ Nein', 'Seppel#$', '-']
# ['Ohler#$', 'Za', 'Schiller (Hannover)#$#$ Nein', 'Severing#$Seydewitz#$', 'krankNein']
# ['-', '-', 'Frau Schilling#$ Nein', 'Silberschmidt#$', 'Nein']
# ['Paeth #$', 'Za', 'Schirmer (Dresden)#$#$', 'Silier (Württemberg)#$', 'entsch.']
# ['Paffehl #$', 'Nein', 'Schirmer (Franken)#$#$ Za', 'Simon (Franken)#$ #$', 'Nein']
# ['Peine#$', '—', 'Schlack#$', 'Simon (Schwaben)#$#$', 'Nein']
# ['Pennemann#$', '—', 'Schlagewerth#$', 'Sinn#$', '-']
# ['Dr. Perlitius#$', 'Za', 'Schlange #$ Za', 'Sollmann#$', 'Nein']
# ['Peters#$', '—', 'Schlecht#$', 'Sonner#$', '-']
# ['Petzold#$', 'Za', 'Schlicke#$ Nein', 'Dr.-Jng. Sorge #$', 'Zabeurl.']
# ['Dr. Pfeffer#$', '—', 'Schlüter#$ Nein', 'Dr. Spahn (Berlin)#$#$', '-']
# ['Pfeiffer#$', '-', 'Schmidt (Berlin)#$ #$ Nein', 'Dr. Spahn (Köln)#$ #$', '-']
# ['Dr. Pfleger#$', 'beurl.', 'Schmidt (Cöpenick)#$#$', 'Sparrer#$', 'Nein']
# ['Frau Pfülf#$', 'Nein', 'Schmidt (Hannover)#$. Za', 'Frau v. Sperber#$', '-']
# ['Dr. Philipp#$', 'Za', 'Schmidt (Hirschberg)#$.', 'Dr. Spuler#$', 'Za']
# ['Dr. vr. Preyer#$', 'Za', 'Schmidt (Meißen)#$#$', '-', '-']
# ['Putz#$', 'Nein', 'Schmidt (Stettin)#$. -. Za', 'Staab#$', 'Nein']
# ['-', '-', 'Schnabrich#$ Nein', '-', '-']
# ['-', '-', '-', 'Stampfer#$', '-']
# ['Dr. Duaatz#$', 'Za', 'Dr. Schnee#$ beurl.', '-', 'Nein']
# ['Dr. Quessel#$', 'Frhr. v. StauffenbergNein', 'Schneider (Berlin)#$ #$ Nein', '-', 'Za']
# ['-', '-', '-', 'Stegerwald#$', '-']
# ['-', '-', 'Dr. Schneider', '-', 'Za']
# ['-', '-', '-', 'Frau Dr. Stegmann.', 'Nein']
# ['Rädel#$', '-', '(Dresden)#$#$ Za', 'Steiger#$', '-']
# ['Dr. Rademacher #$', 'Za', 'Dr. Schneider', 'Dr. Steiniger#$', '-']
# ['v. Ramin#$', '—', '(Thüringen)#$ #$', '-', 'Za']
# ['-', '-', '-', 'Steinkopf#$', 'Nein']
# ['Dr. Raschig#$', '—', 'Schneller#$ Nein', '-', '-']
# ['-', '-', '-', 'Stelling (Oppeln)#$#$', 'Nein']
# ['Rauch (München)#$#$', 'Za', 'Scholem#$', 'Stoecker#$', 'Nein']
# ['v. Raumer#$', '—', 'Dr. Scholz#$', '-', '-']
# ['-', '-', '-', 'Stöhr#$', 'beurl.']
# ['Dr. Reichert#$', 'Za', 'Schöpflin#$ Nein', 'Straßer#$', 'krank']
# ['Frau Reitze#$', 'Nein', 'Frau Schott#$ Za', 'D. Strathmann-----', '-']
# ['Remmele#$', '—', 'Schreck#$', '-', '-']
# ['-', '-', '-', 'Strauß#$', '-']
# ['Graf zu Reventlow#$', 'Nein', 'I)#$. Dr. Schreiber #$ Za', 'Dr. Stresemann #$', 'Za']
# ['Frhr. v. Rheinbaben#$', 'Za', 'Schröder (Mecklen\xad', 'Ströbel#$', 'Nein']
# ['Rheinländer#$', 'Za', 'burg)#$ #$ krank', 'Strötzel#$', 'Nein']
# ['Richter#$', 'beurl.', 'Frau Schroeder', '-', '-']
# ['-', '-', '-', 'Stubbendorff#$', '-']
# ['Frhr. v. Richthofen', '-', '(Schleswig-Holstein)#$ Nein', '-', '-']
# ['-', '-', '-', 'Stücklen#$', 'Nein']
# ['(Breslau)#$#$', 'Za', 'Schröter (Liegnitz)#$#$ Za', '-', '-']
# ['Frhr. v. Richthofen', '-', 'Dr. Schücking#$ Nein', '-', '-']
# ['(Hannover)#$#$', '—', 'Schuldt (Steglitz)#$#$', 'Taubadel#$', 'Nein']
# ['Rieseberg#$', 'Za', 'Graf v. d. Schulenburg Za', 'Frau Teusch#$', 'Za']
# ['Dr. Rießer#$', 'Za', 'Schulte (Breslau)#$#$ 2«', 'Thabor #$', 'krank']
# ['Nippel#$', '—', 'Schultz (Bromberg)#$#$ Za', 'Thälmann#$', '-']
# ['Röder (Baden)#$ #$', 'krank', 'Schulz (Brechen)#$----- Nein', 'Thiel . ^#$', 'Za']
# ['Röder (Franken)#$ . .', 'Za', 'Schulz-Gahmen#$', 'Thomsen#$', 'Za']
# ['Rönneburg#$', 'Nein', 'Schulz (Königsberg)#$. Nein', 'v. Tirpitz#$', '-']
# ['Rosenbaum#$', '—', 'Frau Schulz (Wests.)#$. Nein', 'Torgler#$', 'Nein']
# ['Dr. Rosenberg#$', '—', 'Schulze (Frankfurt)#$#$ Za', 'Tremmel#$', 'Za']
# ['Dr. Rosenfeld#$', 'Nein', 'Schumann (Frankfurt)#$', 'Treviranus#$', '-']
# ['Dr. Roß#$', 'Za', 'Schumann (Stettin)#$ .', 'Troßmann (Nürnberg)#$', '-']

# %%
# importing required modules 
import PyPDF2 
  
# creating a pdf file object 
pdfFileObj = open('../Sample_input_table_data/Roll_Call_5.pdf', 'rb') 
  
# creating a pdf reader object 
pdfReader = PyPDF2.PdfFileReader(pdfFileObj) 
  
# printing number of pages in pdf file 
print(pdfReader.numPages) 
  
# creating a page object 
pageObj = pdfReader.getPage(0) 
  
# extracting text from page 
print(pageObj.extractText()+" adsd") 
  
# closing the pdf file object 
pdfFileObj.close()
# Out:
# 7
#  adsd
