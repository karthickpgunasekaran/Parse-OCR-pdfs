# %%
import pandas as pd
import math
import csv

# %%
#vote clean up 
file_path = "../Data/Input_Step3/vote_names.csv"
data_df = pd.read_csv(file_path)
vote_set ={"za","fa","ja","nein","beurl","krank","entsch","stein","2a","3«","3a","3»"
#,"3st"}
data_list = data_df.values.tolist()

for data_row in data_list:
    for data in data_row:
        #print(data)
        if isinstance(data, float) and math.isnan(data):
            continue
        element = data.split()
        #print("START",element)
        for eachElement in element:
            #print("-"+eachElement.strip()+"-")
            eleProcess = eachElement.strip().lower().replace(".","")
            if len(eleProcess)<=1:
                continue
            vote_set.add(eleProcess)
print("done")
for vote in vote_set:
    print(vote)
# Out:
# START Sozialdemokratische Partei
# START Deutschnationale Bolkspartei
# START Zentrum
# START Deutsche Volkspartei
# START Kommunistische Partei
# START  Deutsche Demokratische Partei
# START Wirtschaftliche Vereinigung
#  (Reichspartei d. deutsch. Mittelstandes,
#  Bayer. Bauern- und Mittelstandsbund,
#  Deutsch-Hannoversche Partei)
# START Bayerische Volkspartei
# START  Deutschvölkische Freiheits- und
#   National sozialist. Deutsche
#   Arbeiter-Partei
#   tVölk. Arbeitsaemcinschaft)
# START Bei keiner Partei
# START Sozialdemokratische Partei
# START  Zentrum
# START Deutsche Volkspartet
# START  Partei
# START   Wirtschaftliche Vereinigung
#  (Reichspartei d. deutsch. Mittelstandes,
#  Bayer. Bauern- und Mittelstandsbund,
#  Dentsch-Hannoversche Partei)
#
# START Deutsche Demokratische Partei
# START Bayerische Bolkspartei
# START Deutschvölkische Freiheitspartei
#  und Nationalsozialist. Deutsche
#  Arbeiter-Partei
#  (Völk. Arbeitsgemeinschaft)
#
# START  Linke Kommunisten
# START  Bei keiner Partei
# START Deutsche Volkspartei
# START Sozialdemokratische Partei
# START Deutsche Volkspartei
# START Zentrum
# START Zentrum
# START Sozialdemokratische Partei
# START Kommunistische Partei
# START Sozialdemokratische Partei
# START Sozias demokratische Partei
# START Deutsch nationale Volkspartei
# START Deutschnationale Volkspartei
# START Sozialdemokratische Partei
# START Sozialdemokratische Partei
# START Deutschnationale Volkspartei
# START Reichswahlvorschlag
# START Sozialdemokratische Partei
# START Deutsche Demo kratische Partei
# START Bayerische Volkspartei Geboren am 10
# START Deutschnationale Volkspartei
# START Zentrum
# START Deutsche Volkspartei
# START Wahlkr
# START Deutschnationale Volkspartei
# START Deutschnationale Volkspartei
# START Zentrum
# START Sozialdemokratische Partei
# START Deutsche Demokratische Partei
# START Deutschnationale Volkspartei
# START Sozialdemokratische Partei
# START Deutsche Demokratische Partei
# START Kommunistische Partei
# START Deutschnationale Volkspartei
# START Zentrum
# START Deutsche Volks partei
# START Deutsche Volkspartei
# START Deutschnationale Volkspartei
# START Sozialdemokratische Partei
# START Deutschnationale Volkspartei
# START Zentrum
# START Sozialdemokratische Partei
# START Zentrum
# START Kommunistische Partei
# START Sozialdemokratische Partei
# START Zentrum
# START Zentrum
# START Mitglied des Reichstags seit 1920
# START Deutschnationale Volkspartei
# START Sozialdemokratische Partei
# START Zentrum
# START Sozialdemokratische Partei
# START Deutschnationale Volkspartei
# START Sozialdemokratische Partei
# START Deutsche Demokratische Partei
# START Deutschnationale Volkspartei
# START Zentrum
# START Deutsche Volks partei
# START Zentrum
# START Kommunistische Partei
# START Sozialdemokratische Partei
# START Deutschnationale Volkspartei
# START Deutsche Demokratische Partei
# START Deutsche Volkspartei
# START Deutsche Volkspartei
# START Kommunistische Partei
# START Zentrum
# START Deutsche Volkspartei
# START Zentrum
# START Deutsche Volkspartei
# START Bayerische Volkspartei
# START Sozialdemokratische Partei
# START Kommunistische Partei
# START Zentrum
# START Deutsch nationale Volkspartei
# START Bayerische Volkspartei
# START Deutsche Demo kratische Partei
# START Nationalsozialistische FreiheitsPartei
# START Deutschnationale Volkspartei
# START Sozialdemokratische Partei
# START Deutschnationale Volkspartei
# START Zentrum
# START Sozialdemokratische Partei
# START Sozialdemokratische Partei
# START Deutschnationale Volkspartei
# START Deutschnationale Volkspartei
# START Deutschnationale Volkspartei
# START Zentrum
# START Deutschnatiouale Volks partei
# START Deutschnationale Volkspartei
# START Sozialdemokratische Partei
# START Zentrum
# START Kommunistische Partei
# START Deutschnationale Volkspartei
# START Bayerische Volkspartei
# START Deutsche Volkspartei
# START Deutsche Demokratische Partei
# START Zentrum
# START Zentrum
# START Deutschnationale Volkspartei
# START Zentrum
# START Zentrum
# START Sozialdemokratische Partei
# START Deutsche Volkspartei
# START Deutsche Demokratische Partei
# START Sozialdemokratische Partei
# START Deutsche Demokratische Partei
# START Sozialdemokratische Partei
# START Kommunistische Partei
# START Deutschnationale Volks partei
# START Nationalsozialistische Freiheitspartei
# START Dkutschnationale Volkspartei
# START Sozialdemokratische Partei
# START Gast der Deutschnationalen Volkspartei
# START Bayerische Volkspartei
# START Deutsch nationale Volkspartei
# START Zentrum
# START Bayerische Volkspartei
# START Kommunistische Partei
# START Sozialdemokratische Partei
# START Zentrum
# START Deutsche Volkspariei
# START Deutschnationale Volkspartei
# START Deutschnationale Volkspartei
# START Kommunistische Partei
# START Deutsche Demokratische Partei
# START Deutschnationale Volkspartei
# START Nationalsozialistische Freiheitspartei
# START Sozialdemo kratische Partei
# START Zentrum
# START Zentrum
# START Deutschnationale Volkspartei
# START Deutsche Demokratische Partei
# START Deutsche Volkspartei
# START Deutschnationale Volkspartei
# START Deutschnationale Volkspartei
# START Deutschnationale Volkspartei
# START Deutschnationale Volkspartei
# START Deutschnationale Volkspartei
# START Kommunistische Partei
# START Sozialdemokratische Partei
# START Deutsche Volkspartei
# START Deutschnationale Volkspartei
# START Sozialdemokratische Partei
# START Deutschnationale Volkspartei
# START Deutsche Volkspartei
# START Bayerische Volkspartei
# START Deutschnationale Volkspartei
# START Zentrum
# START Sozialdemokratische Partei
# START Deutsche Demokratische Partei
# START Sozialdemokratische Partei
# START Sozialdemokratische Partei
# START Sozialdemokratische Partei
# START Sozialdemokratische Partei
# START Zentrum
# START Zentrum
# START Zentrum
# START Kommunistische Partei
# START Wirtschaftliche Vereini gung lWirtschaftspartei des deutschen Mittelstandesst Geboren am 11
# START Sozialdemokratische Partei
# START Kommunistische Partei
# START Deutschnationale Volkspärtei
# START Deutsche Volkspartei
# START Deutschnationale Volkspartei
# START Deutsche Demokratische Partei
# START Sozialdemokra tische Partei
# START Sozialdemokratische Partei
# START Sozialdemokratische Partei
# START Zentrum
# START Sozialdemokratische Partei
# START Kommunistische Partei
# START Deutschnationale Volkspartei
# START Sozialdemokratische Partei
# START Deutsche Volkspartei
# START Zentrum
# START Sozialdemokratische Partei
# START Sozialdemokratische Partei
# START Zentrum
# START Deutsche Volkspartei
# START Deutsche Volkspartei
# START Deutsche Volkspartei
# START Sozialdemokratische Partei
# START Kommunistische Partei
# START Sozialdemokratische Partei
# START Deutsche Volkspartei
# START Deutschnationale Volkspartei
# START Deutsche Volkspartei
# START Kommunistische Partei
# START Zentrum
# START Deutsche Volkspartei
# START Zentrum
# START Deutschnationale Volkspartei
# START Zentrum
# START Deutschnationale Volkspartei
# START Zentrum
# START Deutsche Demo kratische Partei
# START Kommunistische Partei
# START Kommunistische Partei
# START Sozialdemokratische Partei
# START Deutsche Demokratische Partei
# START Deutsche Demokratische Partei
# START Kommunistische Partei
# START Sozialdemokratische Partei
# START Sozialdemokratische Partei
# START Sozialdemokratische Partei
# START Sozialdemokratische Partei
# START Nationalsozialistische Freiheitspartei
# START Sozialdemokratische Partei
# START Deutsche Volkspartei
# START Deutsche Demokratische Partei
# START Sozialdemokratische Partei
# START Teutschnationale Volkspartei
# START Zentrum
# START Bayerische Volkspartei
# START Bayerische Volkspartei
# START Zentrum
# START Sozialdemokratische Partei
# START Deutschnationale Volkspartei
# START Sozialdemokratische Partei
# START Bayerische Volkspartei
# START Deutschnationale Volkspartei
# START Bayerische Volkspartei
# START Deutsche Volks partei
# START Sozialdemokratische Partei
# START Sozialdemokratische Partei
# START Deutschnationale Volkspartei
# START Dentschnationale Volks partei
# START Sozialdemokratische Partei
# START So zialdemokratische Partei
# START Deutschnationale Volkspartei
# START Deutschnationale Volkspartei
# START Bayerische Volkspartei
# START Sozialdemokratische Partei
# START Sozialdemokratische Partei
# START Nationalsozialistische Freiheitspartei
# START Deutschnationale Volkspartei
# START Sozialdemokratische Partei
# START Deutsche Volkspartei
# START Deutschnationale Volkspartei
# START Deutschnationale Volkspartei
# START Deutsche Demokratische Partei
# START Kommunistische Partei
# START Teutsche Volkspartei
# START Deutsche Volkspartei
# START Deutsche Volkspartei
# START Deutsche Volkspartei
# START Sozialdemokratische Partei
# START Deutschnationale Volks partei
# START Deutschnationale Volkspartei
# START Kommunistische Partei
# START Kommunistische Partei
# START Sozialdemokratische Partei
# START Kommunistische Partei
# START Deutsch nationale Volkspartei
# START Zentrum
# START Zentrum
# START Zentrum
# START Zentrum
# START Kommunistische Partei
# START Deutschnationale Volkspartei
# START Deutschnationale Volkspartei
# START Deutschnationale Volks partei
# START Sozialdemokratische Partei
# START Sozialdemokratische Partei
# START Zentrum
# START Zentrum
# START Deutsche Volkspartei
# START Kommunistische Partei
# START Bayerische Volkspartei
# START Sozialdemokratische Partei
# START Kommunistische Partei
# START Sozialdemokratische Partei
# START Kommunistische Partei
# START Nationalsozialistische Freiheitspartei
# START Deutsche Volkspartei
# START Deutschnationale Volts partei
# START Sozialdemokratische Partei
# START Nationalsozialistische Frei heitspartei
# START Deutsche Volkspartei
# START Zentrum
# START Sozialdemokratische Partei
# START Deutschnationale Volkspartei
# START Deutsche Demokratische Partei
# START DeuLschnationale Volkspartei
# START Deutsche Volkspartei
# START Zentrum
# START Deutsche Demokratische Partei
# START Kommunistische Partei
# START Kommunistische Partei
# START Sozialdemokratische Partei
# START Sozial demokratische Partei
# START Sozialdemokratische Partei
# START Sozialdemokratische Partei
# START Sozialdemokratische Partei
# START Teutschnationale Volkspartei
# START Sozialdemokratische Partei
# START Zentrum
# START Sozialdemokratische Partei
# START Sozialdemokratische Partei
# START Sozialdemokratische Partei
# START Sozialdemokratische Partei
# START Kommunistische Partei
# START Deutschnationale Volkspartei
# START Kommunistische Partei
# START Sozialdemokratische Partei
# START Sozialdemokratische Partei
# START Sozialdemokratische Partei
# START Sozial demokratische Partei
# START Deutschnationale Volkspartei
# START Deutsche Volks partei
# START Sozialdemokratische Partei
# START Deutschnationale Volkspartei
# START Sozialdemokratische Partei
# START Deutsche Volkspartei
# START Deutsche Vvlkspartei
# START Kommunistische Partei
# START Kommunistische Partei
# START Deutsche Volkspartei
# START Sozialdemokratische Partei
# START Sozialdemokratische Partei
# START Nationalsozialistische Freiheits partei
# START Deutsch nationale Volkspartei
# START Deutsche Demokratische Partei
# START Deutsche Demokratische Partei
# START Deutschnationale Volkspartei
# START Zentrum
# START 2
# START Sozial demokratische Partei
# START Zentrum
# START Sozialdemokratische Partei
# START Sozialdemokratische Partei
# START TeutschnaLionale Volkspartei
# START Sozialdemo kratische Partei
# START Sozialdemokratische Partei
# START Kommunistische Partei
# START Kommunistische Partei
# START Kommunistische Partei
# START Zentrum
# START Bayerische Volkspartei
# START Sozialdemokratische Partei
# START Deutsche Volkspartei
# START Sozialdemokratische Partei
# START Nationalsozialistische Freiheits partei
# START Sozialdemokratische Partei
# START Sozialdemokratische Partei
# START Sozialdemokratische Partei
# START Sozialdemokratische Partei
# START Sozialdemokratische Partei
# START Deutschnationale Volkspartei
# START Sozialdemokratische Partei
# START Sozialdemokratische Partei
# START Zentrum
# START Sozialdemokratische Partei
# START Zentrum
# START Deutsche Demokratische Partei
# START Deutschnationale Volkspartei
# START Teutschnationale Volkspartei
# START Sozialdemokratische Partei
# START Sozialdemokratische Partei
# START Zentrum
# START Sozialdemokratische Partei
# START Zentrum
# START Deutschnationale Volkspartei
# START Sozialdemokratische Partei
# START Sozialdemokratische Partei
# START Kommunistische Partei
# START Nationalsozialistische Freiheitspartei
# START Nationalsozialistische Freiheitspartei
# START Deutschnationale Volkspartei
# START Von Januar 1919 bis Juni 1920 Mitglied des Bayerischen Landtags
# START Deutsche Volkspartei
# START Sozialdemokratische Partei
# START Kommunistische Partei
# START Deutschnationale Volkspartei
# START Sozialdemokratische Partei
# START Sozialdemokratische Partei
# START Sozialdemokratische Partei
# START Kommunistische Partei
# START Deutsche Volkspartei
# START Deutschnationale Volkspartei
# START Deutschnationale Volkspartei
# START Kommunistische Partei
# START Zentrum
# START Deutschnationale Volkspartei
# START Bayerische Volkspartei
# START Zentrum
# START Sozialdemokratische Partei
# START Kommunistische Partei
# START Sozialdemokratische Partei
# START Deutschnationale Volkspartei
# START Deutsch nationale Volkspartei
# START Zentrum
# START Kommunistische Partei
# START Deutschnationale Volkspartei
# START Zentrum
# START National sozialistische Freiheitspartei
# START Sozialdemokratische Partei
# START Sozialdemokratische Partei
# START Deutschnationale Volkspartei
# START Deutschnationale Volkspartei
# START Deutsche Volkspartei
# START Zentrum
# START Deutsche Demokratische Partei
# START Deutschnationale Volkspartei
# START Zentrum
# START Deutsche Volkspartei
# START Zentrum
# START Sozialdemokratische Partei
# START Deutschnationale Volkspartei
# START Deutschnationale Volkspartei
# START Deutschnationale Volkspartei
# START Deutsche Volkspartei
# START SözialdeMokxatische Partei
# START Kommunistische Partei
# START Deutsche Demokratische Partei
# START Sozialdemokratische Partei
# START Kommunistische Partei
# START Deutschnationale Volkspartei
# START Baye rische Volkspartei
# START Deutsche Volkspartei
# START Kommunistische Partei
# START Zentrum
# START Sozialdemokratische Partei
# START Kommunistische Partei
# START Sozialdemokratische Partei
# START Sozialdemokratische Partei
# START Sozial demokratische Partei
# START Deutsch nationale Volkspartei
# START Sozialdemokratische Partei
# START Deutschnationale Volkspartei
# START Bayerische Volkspartei
# START Deutsch nationale Volkspartei
# START Zentrum
# START Zentrum
# START Sozialdemokratische Partei
# START Deutsche Volkspartei
# START Deutschnationale Volkspartei
# START Sozialdemokratische Partei
# START Zentrum
# START Sozialdemokratische Partei
# START Sozialdemokratische Partei
# START Seit 1920 Mitglied des Reichstags
# START Deutsche Demokratische Partei
# START Kommunistische Partei
# START Deutsche Volks partei
# START Deutsche Volkspartei
# START Sozialdemokratische Partei
# START Zentrum
# START Deutschnationale Volkspartei
# START Sozialdemokratische Partei
# START Kommunistische Partei
# START Zentrum
# START Sozialdemokratische Partei
# START Zentrum
# START Sozialdemokratische Partei
# START Sozialdemokratische Partei
# START Zentrum
# START Zentrum
# START Mitglied des Reichstags seit 1920
# START Sozialdemokratische Partei
# START So zialdemokratische Partei
# START Sozialdemokratische Partei
# START Sozialdemokratische Partei
# START Sozialdemokratische Partei
# START Deutschnationale Volkspartei
# START Zentrum
# START Deutsche Volks partei
# START Nationalsozialistische Deutsche Arbeiter partei
# START Kommunistische Partei
# START Sozialdemokratische Partei
# START Deutsche Demokratische Partei
# START Sozialdemokratische Partei
# START Deutsche Volkspartei
# START Deutsche Volkspartei
# START Sozialdemokratische Partei
# START Zentrum
# START Deutsche Volkspartei
# START Kommunistische Partei
# START Kommu nistische Partei
# START Sozialdemokratische Partei
# START Kommunistische Partei
# START Zentrum
# START Bayerische Volkspartei
# START Deutsche Demokratische Partei
# START Kommunistische Partei
# START Sozialdemokratische Partei
# START Zentrum
# START Deutsche Volkspartei
# START Deutschnationale Volkspartei
# START Sozialdemokratische Partei
# START Deutschnationale Volkspartei
# START Zentrum
# START Nationalsozialistische Deutsche Arbeiterpartei
# START Deutschnationale Volks partei
# START Sozialdemokratische Partei
# START Sozialdemokratische Partei
# START Deutsche Demokratische Partei
# START Zentrum
# START Bayerische Volkspartei
# START Kommunistische Partei
# START Nationalsozialistische Deutsche Arbeiter partei
# START Deutsche Demokratische Partei
# START Zentrum
# START Zentrum
# START Deutschnationale Volkspartei
# START Deutschnationale Volkspartei
# START Kommunistische Partei
# START Zentrum
# START Nationalsozialistische Deutsche Arbeiterpartei
# START Mitglied des Reichstags seit der 2
# START Deutsche Bauernpartei
# START Zentrum
# START Sozialdemokratische Partei
# START Sozialdemokratische Partei
# START Deutsche Volkspartei
# START Deutsche Demokratische Partei
# START Deutsche Demokratische Partei
# START Sozialdemokra tische Partei
# START Kommunistische Partei
# START Zentrum
# START Deutschnationale Volks partei
# START Nationalsozialistische Deutsche Arbeiterpartei
# START Kommunistische Partei
# START Sozialdemokratische Partei
# START Deutschnationale Volkspartei
# START Bayerische Volkspartei
# START Zentrum
# START Sozialdemokratische Partei
# START Deutschnationale Volkspartei
# START Kommunistische Partei
# START Zentrum
# START Deutsche Volkspartei
# START Sozialdemokratische Partei
# START Nationalsozialistische Deutsche Arbeiterpartei
# START Deutsch nationale Volkspartei
# START Deutschnationale Volkspartei
# START Nationalsozialistische Deutsche Arbeiterpartei
# START Deutschnationale Volkspartei
# START Kommunistische Partei
# START Deutschnationale Volkspartei
# START Sozialdemokratische Partei
# START Sozialdemo kratische Partei
# START Sozialdemokratische Partei
# START Zentrum
# START Deutschnationale Volkspartei
# START Deutsche Demokratische Par tei
# START Deutsche Bauernpartei
# START Deutsch nationale Volkspartei
# START Deutschnationale Volkspartei
# START Deutschnationale Volkspartei
# START Zentrum
# START Deutschnationale Volkspartei
# START Kommunistische Partei
# START Sozialdemokratische Partei
# START Sozialdemokratische Partei
# START Kommunistische Partei
# START Sozialdemokratische Partei
# START Deutsche Demokratische Partei
# START Deutschnationale Volkspartei
# START Sozialdemokratische Partei
# START Bayerische Volkspartei
# START Deutschnationale Volkspartei
# START Sozialdemokratische Partei
# START Zentrum
# START Zentrum
# START Deutsche Volkspartei
# START Sozialdemokratische Partei
# START Sozialdemokratische Partei
# START Deutsche Bauernpartei
# START Deutsche Volkspartei
# START Sozialdemokratische Partei
# START Zentrum
# START Kommunistische Partei
# START Bayerische Volkspartei
# START Kommunistische Partei
# START Deutsche Volkspartei
# START Deutsche Volkspartei
# START Deutschnatiormle Volkspartei
# START Deutsche Demokratische Partei
# START Sozialdemokra tische Partei
# START Sozialdemokratische Partei
# START Zentrum
# START Sozialdemokratische Partei
# START Kommunistische Partei
# START Deutschnationale Volkspartei
# START Sozialdemokratische Partei
# START Deutsche Volkspariei
# START Zentrum
# START Sozialdemokratische Partei
# START Sozialdemokratische Partei
# START Deutsche Volkspartei
# START Deutsche Volkspartei
# START Deutsche Volkspartei
# START Sozialdemokratische Partei
# START Kommunistische Partei
# START So zialdemokratische Partei
# START Deutsche Volkspartei
# START Zentrum
# START Deutsche Bauernpartei
# START Deutschnationale Volkspartei
# START Kommunistische Partei
# START Sozialdemokratische Partei
# START Zentrum
# START Deutschnationale Volkspartei
# START Deutsche Demokratische Partei
# START Zentrum
# START Kommunistische Partei
# START Kommunistische Partei
# START Deutsche Volkspartei
# START Sozialdemokratische Partei
# START Sozialdemokratische Partei
# START Sozialdemokratische Partei
# START Zentrum
# START Sozialdemokratische Partei
# START Sozialdemokratische Partei
# START Deutsche Demokratische Partei
# START Sozialdemokratische Partei
# START Sozialdemokratische Partei
# START Sozialdemokratische Partei
# START Deutschnationale Volkspartei
# START Zentrum
# START Sozialdemokratische Partei
# START Bayerische Volkspartei
# START Bayerische Volkspartei
# START Deutschnationale Volkspartei
# START Sozialdemokratische Partei
# START Deutschnationale Volkspartei
# START Bayerische Volkspartei
# START Deutschnationale Volkspartei
# START Deutschnationale Volks partei
# START Deutsche Volkspartei
# START Sozialdemokratische Partei
# START Sozialdemokratische Partei
# START Deutschnationale Volks partei
# START Deutschnationale Volks partei
# START Sozialdemokratische Partei
# START Sozial demokratische Partei
# START Volksrechtpartei
# START Sozialdemokratische Partei
# START Bayerische Volkspartei
# START Sozialdemokratische Partei
# START Sozialdemokratische Partei
# START Deutsche Demo kratische Partei
# START Sozialdemokratische Partei
# START Kommunistische Partei
# START Sozialdemokratische Partei
# START Zentrum
# START Kommunistische Partei
# START Sozialdemokratische Partei
# START Deutschnationale Volkspartei
# START Sozialdemokratische Partei
# START Deutsche Demokratische Partei
# START Kommunistische Partei
# START Kommunistische Partei
# START Deutsche Volkspartei
# START Deutsche Volkspartei
# START Teutschnationale Volkspartei
# START Deutsche Volkspartei
# START Sozialdemokratische Partei
# START Sozialdemokratische Partei
# START Sozialdemokratische Partei
# START Deutschnationale Volkspartei
# START Deutschnationale Volkspartei
# START Zentrum
# START Sozialdemokratische Partei
# START Kommunistische Partei
# START Zentrum
# START Zentrum
# START Zentrum
# START Zentrum
# START Sozialdemokratische Partei
# START Deutschnationale Volkspartei
# START Deutschnationale Volkspartei
# START Kommunistische Partei
# START Kommunistische Partei
# START Sozialdemokratische Partei
# START Sozialdemokratische Partei
# START Zentrum
# START Sozialdemokratische Partei
# START Deutsche Volkspartei
# START Kommunistische Partei
# START Bayerische Volkspartei
# START Sozialdemokratische Partei
# START Deutschnationale Volkspartei
# START Kommunistische Partei
# START Deutschnatronale Volks partei
# START Kommunistische Partei
# START Sozialdemokratische Partei
# START Kommunistische Partei
# START Deutschnationale Volks partei
# START Bayerische Volkspartei
# START Deutsche Volkspartei
# START Sozialdemokratische Partei
# START Deutsche Demokratische Partei
# START Sozialdemokratische Partei
# START Sozialdemokratische Partei
# START Kommunistische Partei
# START Kommu nistische Partei
# START Nationalsozialistische Deutsche Arbeiterpartei
# START Deutsche Volkspartei
# START Sozialdemokratische Partei
# START Sozialdemokratische Partei
# START Deutschnationale Volkspartei
# START Zentrum
# START Deutsche Demokratische Partei
# START Sozialdemokratische Partei
# START Sozial demokratische Partei
# START Deutsche Volkspartei
# START Sozialdemokratische Partei
# START Sozialdemokratische Partei
# START Sozialdemokratische Partei
# START Sozialdemokratische Partei
# START Sozialdemokratische Partei
# START Deutschnationale Volkspartei
# START Sozialdemokratische Partei
# START Sozialdemokratische Partei
# START Sozialdemo kratische Partei
# START Zentrum
# START Deutschnationale Volkspartei
# START Sozialdemokratische Partei
# START Sozialdemokratische Partei
# START Deutsche Volkspartei
# START Sozialdemokratische Partei
# START Sozialdemokratische Partei
# START Deutschnationale Volkspartei
# START Sozialdemokratische Partei
# START Deutschnationale Volkspartei
# START Bayerische Volkspartei
# START Kommunistische Partei
# START Sozialdemokratische Partei
# START Deutsche Volkspartei
# START Deutsche Demokratische Partei
# START Deutsche Volks partei
# START Kommunistische Partei
# START Deutsche Volkspartei
# START Sozialdemokratische Partei
# START Kommunistische Partei
# START Sozialdemokratische Partei
# START Sozialdemokratische Partei
# START Sozialdemokratische Partei
# START Deutsch nationale Volkspartei
# START Kommunistische Partei
# START Deutsche Demokratische Partei
# START Deutschnationale Volkspartei
# START Sozialdemokratische Partei
# START Zentrum
# START Sozialdemokratische Partei
# START Sozialdemokratische Partei
# START Sozialdemokratische Partei
# START Kommunistische Partei
# START Sozialdemokratische Partei
# START Zentrum
# START Bayerische Volkspartei
# START Sozialdemokratische Partei
# START Sozialdemokratische Partei
# START Sozialdemokratische Partei
# START Sozialdemokratische Partei
# START Sozialdemokratische Partei
# START Sozialdemokratische Par tei
# START Sozialdemokratische Partei
# START Zentrum
# START Sozialdemokratische Partei
# START Deutschnationale Volkspartei
# START Deutschnationale Volkspartei
# START Deutsche Demokratische Partei
# START Sozialdemokratische Partei
# START Deutschnationale Volkspartei
# START Sozialdemokratische Partei
# START Sozialdemokratische Partei
# START Teutschnationale Volkspartei
# START Sozialdemokratische Partei
# START Sozialdemokratische Partei
# START Kommunistische Partei
# START Nationalsozialistische Deutsche Arbeiterpartei
# START Nationalsozialistische Deutsche Arbeiterpartei
# START Deutschnationale Volkspartei
# START Von Januar 1919 bis Juni 1920 Mitglied des Bayerischen Landtags
# START Deutsche Volkspartei
# START Sozialdemokratische Partei
# START Kommunistische Partei
# START Deutschnationale Volkspartei
# START Sozialdemokratische Partei
# START Deutsche Demokratische Partei
# START Sozialdemokratische Partei
# START Zentrum
# START Sozialdemokratische Partei
# START Kommunistische Partei
# START Kommunistische Partei
# START Deutsche Volkspartei
# START Kommunistische Partei
# START Bayerische Volkspartei
# START Kommunistische Partei
# START Sozialdemokratische Partei
# START Sozialdemokratische Partei
# START Sozialdemokratische Partei
# START Kommunistische Partei
# START Nationalsozialistische Deutsche Arbeiterpartei
# START Deutschnationale Volkspartei
# START Zentrum
# START Zentrum
# START Zentrum
# START Sozialdemokratische Partei
# START Sozialdemokratische Partei
# START Sozialdemokratische Partei
# START Deutschnationale Volkspartei
# START Zentrum
# START Deutsche Demokratische Partei
# START Deutschnationale Volkspartei
# START Zentrum
# START Nationalsozialistische deutsche Arbeiterpartei
# START Zentrum
# START Sozialdemokratische Partei
# START Sozialdemokratische Partei
# START Deutschnationale Volkspartei
# START Deutsche Volkspartei
# START Deutsche Volkspartei
# START Kommunistische Partei
# START Deutsche Demokratische Partei
# START Deutschnationale Volkspartei
# START Sozialdemokratische Partei
# done

# %%
#Party cleanup

# %%
vote_list = list(vote_set)
with open('vote_names.csv','w') as result_file:
    wr = csv.writer(result_file, dialect='excel')
    #for item_val in vote_list:
    wr.writerow(item_val)

# %%
df = pd.DataFrame(list(vote_set))
df.to_csv("vote_names.csv")

# %%
#party cleanup
file_path = "../Data/Input_Step3/party_names_old_complete.csv"
data_df = pd.read_csv(file_path)
party_set =set()#{"za","fa","ja","nein","beurl","krank","entsch","stein","2a","3«","3a","3»"
#,"3st"}
data_list = data_df.values.tolist()

for data_row in data_list:
    for data in data_row:
        #print(data)
        if isinstance(data, float) and math.isnan(data):
            continue
        element = data#.split()
        #print("START",element)
        #for eachElement in element:
        #print("-"+eachElement.strip()+"-")
        eleProcess = element.strip().lower()#.replace(".","")
        if len(eleProcess)<=1:
            continue
        party_set.add(eleProcess)
print("done")
for party in party_set:
    print("END",party)
# Out:
# done
# END bayerische bolkspartei
# END deutschnationale volts partei
# END deutsche volks partei
# END teutschnalionale volkspartei
# END national sozialistische freiheitspartei
# END dkutschnationale volkspartei
# END teutsche volkspartei
# END mitglied des reichstags seit der 2
# END gast der deutschnationalen volkspartei
# END volksrechtpartei
# END deulschnationale volkspartei
# END nationalsozialistische frei heitspartei
# END kommu nistische partei
# END partei
# END von januar 1919 bis juni 1920 mitglied des bayerischen landtags
# END deutschnationale bolkspartei
# END nationalsozialistische deutsche arbeiter partei
# END sozial demokratische partei
# END deutsche volkspariei
# END zentrum
# END mitglied des reichstags seit 1920
# END nationalsozialistische freiheits partei
# END seit 1920 mitglied des reichstags
# END deutsche demokratische partei
# END nationalsozialistische freiheitspartei
# END kommunistische partei
# END wirtschaftliche vereini gung lwirtschaftspartei des deutschen mittelstandesst geboren am 11
# END deutschnationale volkspärtei
# END sozialdemokratische partei
# END deutschnatiormle volkspartei
# END deutschnatiouale volks partei
# END linke kommunisten
# END deutsche demo kratische partei
# END sozias demokratische partei
# END dentschnationale volks partei
# END deutschnatronale volks partei
# END baye rische volkspartei
# END deutsche volkspartei
# END wirtschaftliche vereinigung
#  (reichspartei d deutsch mittelstandes,
#  bayer bauern- und mittelstandsbund,
#  dentsch-hannoversche partei)
# END sözialdemokxatische partei
# END sozialdemokratische par tei
# END sozialdemo kratische partei
# END deutschvölkische freiheits- und
#   national sozialist deutsche
#   arbeiter-partei
#   tvölk arbeitsaemcinschaft)
# END deutsche vvlkspartei
# END wirtschaftliche vereinigung
#  (reichspartei d deutsch mittelstandes,
#  bayer bauern- und mittelstandsbund,
#  deutsch-hannoversche partei)
# END sozialdemokra tische partei
# END reichswahlvorschlag
# END bei keiner partei
# END so zialdemokratische partei
# END wahlkr
# END teutschnationale volkspartei
# END deutsche bauernpartei
# END deutsche volkspartet
# END nationalsozialistische deutsche arbeiterpartei
# END deutschnationale volks partei
# END bayerische volkspartei
# END deutschvölkische freiheitspartei
#  und nationalsozialist deutsche
#  arbeiter-partei
#  (völk arbeitsgemeinschaft)
# END deutschnationale volkspartei
# END bayerische volkspartei geboren am 10
# END deutsch nationale volkspartei
# END deutsche demokratische par tei

# %%
df = pd.DataFrame(list(party_set))
df.to_csv("../Data/Input_Step3/party_names.csv")
